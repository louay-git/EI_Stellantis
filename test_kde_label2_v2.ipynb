# %% [markdown]
# ----
# Détection de défauts - EI Stellantis
# ----

# %% [markdown]
# ---
# Dataset 1
# ---

# %%
import os
import pandas as pd 
import matplotlib.pyplot as plt
import tsfel
import time
import numpy as np

# %%
nSet = 0
fileTS = os.path.join(os.getcwd(), "pdfTimeSeries{:d}.pkl".format(nSet))
pdfTS = pd.read_pickle(fileTS)

# %%
pdfTS
# Out:
#             u         y          i         e
# 0    0.000000 -0.076287  9N6FK96G8 -0.076287
# 1    0.000000  0.019506  9N6FK96G8  0.019506
# 2    0.000000 -0.073928  9N6FK96G8 -0.073928
# 3    0.000000  0.044727  9N6FK96G8  0.044727
# 4    0.000000 -0.010317  9N6FK96G8 -0.010317
# ..        ...       ...        ...       ...
# 718 -0.465181 -0.449052  UMTMULQVC  0.016130
# 719 -0.465181 -0.417802  UMTMULQVC  0.047379
# 720 -0.465181 -0.510018  UMTMULQVC -0.044837
# 721 -0.465181 -0.507332  UMTMULQVC -0.042151
# 722 -0.465181 -0.447438  UMTMULQVC  0.017743
#
# [247976 rows x 4 columns]

# %%
identifiant = "UMTMULQVC"

pdfTS_filtre = pdfTS[pdfTS["i"] == identifiant]

pdfTS_filtre["u"].plot(label="Entrée")
pdfTS_filtre["y"].plot(label="Sortie")


plt.xlabel("Indice de la ligne")
plt.ylabel("Valeur")
plt.title(f"Signaux pour i = {identifiant}")
plt.grid()
plt.legend()
plt.show()

# %%
fileEF = os.path.join(os.getcwd(), "pdfFeatures{:d}.pkl".format(nSet))
pdfEF = pd.read_pickle(fileEF)

# %%
pdfEF
# Out:
#       e_Absolute energy e_Area under the curve e_Autocorrelation  \
# 0              0.030425               0.057124               1.0
# 1              0.034108               0.071956               2.0
# 2              0.042274               0.083902               1.0
# 3              0.033578               0.080128               2.0
# 4              0.023003               0.049324               1.0
# ...                 ...                    ...               ...
# 49311          0.058049               0.090205               1.0
# 49312          0.035514               0.066874               1.0
# 49313          0.035254               0.063878               1.0
# 49314          0.041431               0.080162               1.0
# 49315          0.033175               0.075705               1.0
#
#       e_Average power e_Centroid e_ECDF Percentile Count_0  \
# 0            0.016903   0.799343                       2.0
# 1            0.018949   0.870813                       2.0
# 2            0.023486   0.962404                       2.0
# 3            0.018654   0.551002                       2.0
# 4            0.012779   1.067663                       2.0
# ...               ...        ...                       ...
# 49311        0.032249   0.799835                       2.0
# 49312         0.01973   0.918799                       2.0
# 49313        0.019586   0.700099                       2.0
# 49314        0.023017   1.048823                       2.0
# 49315         0.01843   0.694141                       2.0
#
#       e_ECDF Percentile Count_1 e_ECDF Percentile_0 e_ECDF Percentile_1  \
# 0                           8.0           -0.073928            0.044727
# 1                           8.0           -0.068527            0.031442
# 2                           8.0           -0.105961            0.016858
# 3                           8.0           -0.104259            0.021024
# 4                           8.0           -0.015203            0.035602
# ...                         ...                 ...                 ...
# 49311                       8.0           -0.087101            0.032083
# 49312                       8.0           -0.038623            0.032083
# 49313                       8.0           -0.038623            0.070625
# 49314                       8.0           -0.073158            0.060267
# 49315                       8.0           -0.073158            0.039404
#
#       e_ECDF_0  ... y_Wavelet variance_1 y_Wavelet variance_2  \
# 0          0.1  ...             0.004341             0.003173
# 1          0.1  ...             0.003611             0.003788
# 2          0.1  ...             0.001518             0.000854
# 3          0.1  ...             0.007749             0.006425
# 4          0.1  ...               0.0012             0.001165
# ...        ...  ...                  ...                  ...
# 49311      0.1  ...             0.031444             0.015267
# 49312      0.1  ...             0.017774             0.017436
# 49313      0.1  ...             0.012935             0.018426
# 49314      0.1  ...             0.032227             0.018178
# 49315      0.1  ...              0.01753             0.027246
#
#       y_Wavelet variance_3 y_Wavelet variance_4 y_Wavelet variance_5  \
# 0                 0.001785              0.00109             0.000761
# 1                 0.003008             0.002341             0.001897
# 2                 0.000852             0.000831             0.000794
# 3                  0.00425             0.003015             0.002334
# 4                 0.000987             0.000811             0.000682
# ...                    ...                  ...                  ...
# 49311             0.019952             0.027048             0.031054
# 49312             0.023716             0.028415             0.030289
# 49313             0.027143             0.031986             0.033404
# 49314              0.02272             0.029591             0.033423
# 49315             0.036991             0.041222             0.041671
#
#       y_Wavelet variance_6 y_Wavelet variance_7 y_Wavelet variance_8  \
# 0                  0.00059             0.000489             0.000423
# 1                 0.001597             0.001382             0.001221
# 2                 0.000749             0.000702             0.000656
# 3                 0.001921             0.001645             0.001445
# 4                  0.00059              0.00052             0.000465
# ...                    ...                  ...                  ...
# 49311             0.032461             0.032345             0.031438
# 49312             0.030336              0.02944             0.028123
# 49313             0.032951             0.031636             0.029988
# 49314             0.034674             0.034409             0.033364
# 49315             0.040293             0.038184             0.035874
#
#       y_Zero crossing rate          i
# 0                      6.0  9N6FK96G8
# 1                      4.0  9N6FK96G8
# 2                      4.0  9N6FK96G8
# 3                      3.0  9N6FK96G8
# 4                      4.0  9N6FK96G8
# ...                    ...        ...
# 49311                  0.0  UMTMULQVC
# 49312                  0.0  UMTMULQVC
# 49313                  0.0  UMTMULQVC
# 49314                  0.0  UMTMULQVC
# 49315                  0.0  UMTMULQVC
#
# [49316 rows x 275 columns]

# %% [markdown]
# ***DATA PREP***

# %% [markdown]
# Step 1,2,3 : Cleaning, scaling and spliting data

# %%
import numpy as np
import pandas as pd

# Copie du dataframe de features
df = pdfEF.copy()

# On enlève l'identifiant des features si la colonne existe
X = df.drop(columns=["i"], errors="ignore")

# Conversion en numérique
X = X.apply(pd.to_numeric, errors="coerce")

# Remplacement des valeurs infinies
X = X.replace([np.inf, -np.inf], np.nan)

# Suppression des colonnes complètement vides
X = X.dropna(axis=1, how="all")

# Remplacement des valeurs manquantes par la médiane
X = X.fillna(X.median())

# Suppression des colonnes constantes
X = X.loc[:, X.nunique(dropna=True) > 1]

print("Shape après cleaning :", X.shape)
# Out:
# Shape après cleaning : (49316, 246)

# %% [markdown]
# Split

# %%
from sklearn.model_selection import train_test_split

# Indices pour retrouver les lignes originales après le split
indices = np.arange(X.shape[0])

X_train, X_test, idx_train, idx_test = train_test_split(
    X,
    indices,
    test_size=0.2,
    random_state=42,
    shuffle=True
)

print("X_train :", X_train.shape)
print("X_test :", X_test.shape)
# Out:
# X_train : (39452, 246)
# X_test : (9864, 246)

# %% [markdown]
# Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Scaling terminé")
# Out:
# Scaling terminé

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.7, random_state=42)

X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

print("Nombre de features au départ :", X.shape[1])
print("Nombre de composantes PCA gardées :", X_train_pca.shape[1])
print("Variance expliquée :", round(pca.explained_variance_ratio_.sum(), 4))
# Out:
# Nombre de features au départ : 246
# Nombre de composantes PCA gardées : 14
# Variance expliquée : 0.7042

# %% [markdown]
# **Kernel Density Estimation**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KernelDensity
import time

t0 = time.time()

# Split du train PCA en :
# - une partie pour entraîner la KDE
# - une partie pour définir le seuil de vraisemblance
X_kde_train, X_kde_val = train_test_split(
    X_train_pca,
    test_size=0.3,
    random_state=42,
    shuffle=True
)

# Échantillon pour accélérer la KDE
n_sample = min(3000, len(X_kde_train))

sample_idx = np.random.choice(
    len(X_kde_train),
    size=n_sample,
    replace=False
)

X_kde_sample = X_kde_train[sample_idx]

print("Taille utilisée pour KDE :", X_kde_sample.shape)

# Intervalle borné de recherche du bandwidth
bandwidth_min = 0.1
bandwidth_max = 2.0
nb_tests = 10

bandwidth_values = np.linspace(
    bandwidth_min,
    bandwidth_max,
    nb_tests
)

params = {
    "bandwidth": bandwidth_values
}

# Recherche du meilleur bandwidth
grid = GridSearchCV(
    KernelDensity(kernel="gaussian"),
    params,
    cv=3
)

grid.fit(X_kde_sample)

best_bandwidth = grid.best_params_["bandwidth"]

print("Meilleur bandwidth trouvé :", best_bandwidth)

# KDE final avec le meilleur bandwidth
kde = KernelDensity(
    kernel="gaussian",
    bandwidth=best_bandwidth
)

kde.fit(X_kde_sample)

print("Temps entraînement KDE :", round(time.time() - t0, 2), "secondes")
# Out:
# Taille utilisée pour KDE : (3000, 14)
# Meilleur bandwidth trouvé : 1.1555555555555557
# Temps entraînement KDE : 2.71 secondes

# %%
# Log-vraisemblance sur validation et test
val_log_likelihood = kde.score_samples(X_kde_val)
test_log_likelihood = kde.score_samples(X_test_pca)

# Seuil : les 20% avec la plus faible vraisemblance sont considérés comme points de bord
threshold = np.percentile(val_log_likelihood, 20)

# Détection sur le test
test_is_border = test_log_likelihood < threshold

print("Seuil de log-vraisemblance :", threshold)
print("Nombre de points test :", len(test_is_border))
print("Points sur les bords :", test_is_border.sum())
print("Pourcentage :", round(test_is_border.mean() * 100, 2), "%")
# Out:
# Seuil de log-vraisemblance : -29.624444914674548
# Nombre de points test : 9864
# Points sur les bords : 1936
# Pourcentage : 19.63 %

# %%
df_test_result = df.iloc[idx_test].copy()

df_test_result["log_likelihood"] = test_log_likelihood
df_test_result["is_border"] = test_is_border

df_test_result[["log_likelihood", "is_border"]].head(20)
# Out:
#        log_likelihood  is_border
# 48186      -24.450545      False
# 38307      -28.453598      False
# 47752      -23.718580      False
# 44372      -24.580130      False
# 147        -28.378210      False
# 14174      -26.276367      False
# 28078      -26.776544      False
# 6095       -23.991101      False
# 37486      -25.395714      False
# 33555      -26.504623      False
# 19485      -25.642151      False
# 25648      -28.139266      False
# 17731      -25.963048      False
# 22136      -28.102662      False
# 23187      -38.687424       True
# 21361      -29.715067       True
# 17280      -31.922943       True
# 6921       -25.881895      False
# 33237      -23.945826      False
# 3780       -25.196042      False

# %%
df_test_result.sort_values("log_likelihood")[["log_likelihood", "is_border"]].head(20)
# Out:
#        log_likelihood  is_border
# 39846     -149.741348       True
# 30240     -124.596031       True
# 38533     -124.299563       True
# 41593      -89.168294       True
# 41595      -86.390685       True
# 31754      -81.158825       True
# 13413      -75.705288       True
# 18236      -73.397375       True
# 12581      -73.299641       True
# 24389      -70.375670       True
# 11948      -69.505356       True
# 6887       -69.344549       True
# 38332      -68.161604       True
# 11601      -67.541625       True
# 6567       -66.688728       True
# 22224      -65.669220       True
# 10079      -65.172684       True
# 17894      -65.108667       True
# 29468      -63.946330       True
# 17164      -63.470797       True

# %%
import matplotlib.pyplot as plt

all_scores = np.concatenate([val_log_likelihood, test_log_likelihood])

xmin = np.percentile(all_scores, 1)
xmax = np.percentile(all_scores, 99)

plt.figure(figsize=(10, 5))

plt.hist(
    val_log_likelihood,
    bins=50,
    density=True,
    alpha=0.5,
    label="Validation"
)

plt.hist(
    test_log_likelihood,
    bins=50,
    density=True,
    alpha=0.5,
    label="Test"
)

plt.axvline(
    threshold,
    linestyle="--",
    label="Seuil"
)

plt.xlim(xmin, xmax)

plt.xlabel("Log-vraisemblance")
plt.ylabel("Densité")
plt.title("Distribution des log-vraisemblances KDE")
plt.legend()
plt.grid()
plt.show()

# %%
sorted_scores = np.sort(test_log_likelihood)

plt.figure(figsize=(10, 5))

plt.plot(sorted_scores)
plt.axhline(threshold, linestyle="--", label="Seuil")

plt.xlabel("Points test triés")
plt.ylabel("Log-vraisemblance")
plt.title("Log-vraisemblance des points test")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6))

plt.scatter(
    X_test_pca[:, 0],
    X_test_pca[:, 1],
    c=test_is_border,
    s=8
)

plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.title("Points sur les bords détectés par KDE")
plt.grid()
plt.show()

# %% [markdown]
# ---
# ****Fichier avec défaut 1****
# ---

# %%
nSet = 0
fileTS_def = os.path.join(os.getcwd(), "pdfTimeSeries1.pkl".format(nSet))
pdfTS_def = pd.read_pickle(fileTS_def)

# %%
pdfTS_def
# Out:
#              u         y          i         e
# 0     0.000000 -0.178862  VJG2XDS11 -0.178862
# 1     0.000000  0.009132  VJG2XDS11  0.009132
# 2     0.000000  0.058681  VJG2XDS11  0.058681
# 3     0.000000  0.010686  VJG2XDS11  0.010686
# 4     0.000000 -0.001032  VJG2XDS11 -0.001032
# ...        ...       ...        ...       ...
# 1805  0.933992  0.924232  RJ9RSGP8N -0.009760
# 1806  0.933992  1.047756  RJ9RSGP8N  0.113764
# 1807  0.933992  0.923011  RJ9RSGP8N -0.010981
# 1808  0.933992  0.878074  RJ9RSGP8N -0.055918
# 1809  0.933992  0.822133  RJ9RSGP8N -0.111859
#
# [50185 rows x 4 columns]

# %%
identifiant = "RJ9RSGP8N"

pdfTSdef_filtre = pdfTS_def[pdfTS_def["i"] == identifiant]

pdfTSdef_filtre["u"].plot(label="Entrée")
pdfTSdef_filtre["y"].plot(label="Sortie")

plt.xlabel("Indice de la ligne")
plt.ylabel("Valeur")
plt.title(f"Signaux pour i = {identifiant}")
plt.grid()
plt.legend()
plt.show()

# %%
fileEF_default = os.path.join(os.getcwd(), "pdfFeatures1.pkl".format(nSet))
pdfEF_default = pd.read_pickle(fileEF_default)

# %%
pdfEF_default
# Out:
#      e_Absolute energy e_Area under the curve e_Autocorrelation  \
# 0             0.079972               0.070585               1.0
# 1             0.113216               0.108242               1.0
# 2             0.080514               0.102533               1.0
# 3             0.041541               0.086099               1.0
# 4             0.032314               0.046819               1.0
# ...                ...                    ...               ...
# 9978          0.043084               0.066947               1.0
# 9979          0.056206               0.071727               1.0
# 9980          0.098005               0.111591               1.0
# 9981          0.067764                0.08189               1.0
# 9982          0.032551               0.061305               1.0
#
#      e_Average power e_Centroid e_ECDF Percentile Count_0  \
# 0           0.044429   0.743867                       2.0
# 1           0.062898   1.067862                       2.0
# 2            0.04473   0.673056                       2.0
# 3           0.023078   0.947138                       2.0
# 4           0.017952   0.264517                       2.0
# ...              ...        ...                       ...
# 9978        0.023935   0.874975                       2.0
# 9979        0.031225   1.017963                       2.0
# 9980        0.054447   1.168855                       2.0
# 9981        0.037647    0.58618                       2.0
# 9982        0.018084   1.387666                       2.0
#
#      e_ECDF Percentile Count_1 e_ECDF Percentile_0 e_ECDF Percentile_1  \
# 0                          8.0            -0.16203            0.058681
# 1                          8.0            -0.16203            0.070568
# 2                          8.0           -0.071974            0.020168
# 3                          8.0           -0.089413            0.004123
# 4                          8.0           -0.089413            0.017185
# ...                        ...                 ...                 ...
# 9978                       8.0           -0.070085            0.036081
# 9979                       8.0           -0.070085            0.086244
# 9980                       8.0           -0.100425            0.089533
# 9981                       8.0            -0.01493            0.034071
# 9982                       8.0           -0.055918            0.034071
#
#      e_ECDF_0  ... y_Wavelet variance_1 y_Wavelet variance_2  \
# 0         0.1  ...             0.006549             0.002512
# 1         0.1  ...             0.012497             0.004955
# 2         0.1  ...              0.00544             0.003927
# 3         0.1  ...             0.000665             0.000911
# 4         0.1  ...             0.002195             0.002557
# ...       ...  ...                  ...                  ...
# 9978      0.1  ...             0.050158             0.070849
# 9979      0.1  ...             0.062573              0.06251
# 9980      0.1  ...             0.062877             0.070356
# 9981      0.1  ...             0.056094             0.081339
# 9982      0.1  ...             0.044195             0.071248
#
#      y_Wavelet variance_3 y_Wavelet variance_4 y_Wavelet variance_5  \
# 0                0.000561             0.000079             0.000034
# 1                0.001334             0.000357             0.000192
# 2                0.002602             0.001843             0.001432
# 3                0.000832             0.000722             0.000634
# 4                0.002071             0.001648             0.001362
# ...                   ...                  ...                  ...
# 9978             0.107633             0.130185               0.1382
# 9979             0.095131             0.120334             0.131557
# 9980             0.103128             0.127363             0.137766
# 9981             0.119263             0.141201             0.148211
# 9982             0.110494             0.132745             0.139952
#
#      y_Wavelet variance_6 y_Wavelet variance_7 y_Wavelet variance_8  \
# 0                0.000084             0.000139              0.00018
# 1                0.000225             0.000287             0.000336
# 2                0.001188             0.001027             0.000911
# 3                0.000565             0.000509             0.000463
# 4                0.001164             0.001019             0.000907
# ...                   ...                  ...                  ...
# 9978             0.137748             0.133162              0.12683
# 9979             0.133555             0.130661             0.125468
# 9980             0.139117             0.135697             0.130065
# 9981             0.146773             0.141318             0.134241
# 9982             0.138808             0.133724             0.127053
#
#      y_Zero crossing rate          i
# 0                     7.0  VJG2XDS11
# 1                     5.0  VJG2XDS11
# 2                     3.0  VJG2XDS11
# 3                     4.0  VJG2XDS11
# 4                     6.0  VJG2XDS11
# ...                   ...        ...
# 9978                  0.0  RJ9RSGP8N
# 9979                  0.0  RJ9RSGP8N
# 9980                  0.0  RJ9RSGP8N
# 9981                  0.0  RJ9RSGP8N
# 9982                  0.0  RJ9RSGP8N
#
# [9983 rows x 275 columns]

# %%
# =====================================================
# 1. Préparation du dataframe défaut dataset1
# =====================================================

df_default_original = pdfEF_default.copy()

# On enlève l'identifiant si présent
X_default = df_default_original.drop(columns=["i"], errors="ignore")

# Conversion en numérique
X_default = X_default.apply(pd.to_numeric, errors="coerce")

# Remplacement des valeurs infinies
X_default = X_default.replace([np.inf, -np.inf], np.nan)

# =====================================================
# 2. Alignement avec les colonnes utilisées sur le dataset sain
# =====================================================

for col in X.columns:
    if col not in X_default.columns:
        X_default[col] = np.nan

# Même ordre de colonnes que le dataset sain
X_default = X_default[X.columns]

# Remplacement des NaN avec la médiane du dataset sain
X_default = X_default.fillna(X.median())

# Sécurité finale
X_default = X_default.replace([np.inf, -np.inf], np.nan)
X_default = X_default.fillna(X.median())

print("Shape défaut après préparation :", X_default.shape)
# Out:
# Shape défaut après préparation : (9983, 246)

# %%
# =====================================================
# 3. Application du pipeline appris sur les données saines
# =====================================================

X_default_scaled = scaler.transform(X_default)

X_default_pca = pca.transform(X_default_scaled)

default_log_likelihood = kde.score_samples(X_default_pca)

# %%
# =====================================================
# 4. Création du dataframe résultat défaut
# =====================================================

df_default_result = df_default_original.copy()

df_default_result["log_likelihood"] = default_log_likelihood
df_default_result["is_border"] = df_default_result["log_likelihood"] < threshold
df_default_result["is_normal"] = df_default_result["log_likelihood"] >= threshold
df_default_result["anomaly_score"] = -df_default_result["log_likelihood"]

df_default_result[["i", "log_likelihood", "is_normal", "is_border", "anomaly_score"]].head()
# Out:
#            i  log_likelihood  is_normal  is_border  anomaly_score
# 0  VJG2XDS11      -25.783404       True      False      25.783404
# 1  VJG2XDS11      -31.008270      False       True      31.008270
# 2  VJG2XDS11      -26.175512       True      False      26.175512
# 3  VJG2XDS11      -30.600474      False       True      30.600474
# 4  VJG2XDS11      -27.048149       True      False      27.048149

# %%
# Recalcul du statut de chaque fenêtre défaut à partir du seuil KDE
df_default_result["is_border"] = df_default_result["log_likelihood"] < threshold
df_default_result["is_normal"] = df_default_result["log_likelihood"] >= threshold

# Score d'anomalie
df_default_result["anomaly_score"] = -df_default_result["log_likelihood"]

df_default_result[["i", "log_likelihood", "is_normal", "is_border", "anomaly_score"]].head()
# Out:
#            i  log_likelihood  is_normal  is_border  anomaly_score
# 0  VJG2XDS11      -25.783404       True      False      25.783404
# 1  VJG2XDS11      -31.008270      False       True      31.008270
# 2  VJG2XDS11      -26.175512       True      False      26.175512
# 3  VJG2XDS11      -30.600474      False       True      30.600474
# 4  VJG2XDS11      -27.048149       True      False      27.048149

# %%
# =====================================================
# Agrégation des fenêtres défauts par identifiant
# =====================================================

summary_default = df_default_result.groupby("i").agg(
    nb_windows=("is_border", "count"),
    nb_windows_anormales=("is_border", "sum"),
    pct_windows_anormales=("is_border", "mean"),
    mean_log_likelihood=("log_likelihood", "mean"),
    min_log_likelihood=("log_likelihood", "min"),
    max_anomaly_score=("anomaly_score", "max"),
    mean_anomaly_score=("anomaly_score", "mean")
).reset_index()

# Conversion en pourcentage
summary_default["pct_windows_anormales"] = summary_default["pct_windows_anormales"] * 100

summary_default.head()
# Out:
#            i  nb_windows  nb_windows_anormales  pct_windows_anormales  \
# 0  2U2HN8U8D         323                   107              33.126935
# 1  3A2AKKKHI         314                    76              24.203822
# 2  48WK1UQQO         329                   111              33.738602
# 3  6QXC4QTK2         203                    61              30.049261
# 4  87UUY7547         242                    75              30.991736
#
#    mean_log_likelihood  min_log_likelihood  max_anomaly_score  \
# 0           -31.035764         -127.484931         127.484931
# 1           -43.992415        -1490.204692        1490.204692
# 2           -35.881678         -372.924157         372.924157
# 3           -32.073609         -119.139260         119.139260
# 4           -46.203388         -664.617042         664.617042
#
#    mean_anomaly_score
# 0           31.035764
# 1           43.992415
# 2           35.881678
# 3           32.073609
# 4           46.203388

# %%
seuil_id = 10

summary_default["id_detected_faulty"] = summary_default["pct_windows_anormales"] >= seuil_id

summary_default[[
    "i",
    "nb_windows",
    "nb_windows_anormales",
    "pct_windows_anormales",
    "id_detected_faulty"
]].head(20)
# Out:
#             i  nb_windows  nb_windows_anormales  pct_windows_anormales  \
# 0   2U2HN8U8D         323                   107              33.126935
# 1   3A2AKKKHI         314                    76              24.203822
# 2   48WK1UQQO         329                   111              33.738602
# 3   6QXC4QTK2         203                    61              30.049261
# 4   87UUY7547         242                    75              30.991736
# 5   8IWYZ3WFE         187                    57              30.481283
# 6   9DI4D2S36         162                    61              37.654321
# 7   AQ86JGMKW         232                    79              34.051724
# 8   AZTVA5ZWX         259                    90              34.749035
# 9   D3R3JJGIL         314                    93              29.617834
# 10  D4GYUVE1L         176                    53              30.113636
# 11  DVQ8RBHH6         286                    86              30.069930
# 12  FKSY1Y1K5         274                    70              25.547445
# 13  FUUSH5WWX         258                    82              31.782946
# 14  G0YTI4U8S         280                    98              35.000000
# 15  GAJOFQ4RL         205                    77              37.560976
# 16  GF0FTT8Z7         302                    95              31.456954
# 17  KIQ82T2TF         142                    65              45.774648
# 18  KOTSIR47O         225                    74              32.888889
# 19  N5PJJE2ET         261                    95              36.398467
#
#     id_detected_faulty
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
# 5                 True
# 6                 True
# 7                 True
# 8                 True
# 9                 True
# 10                True
# 11                True
# 12                True
# 13                True
# 14                True
# 15                True
# 16                True
# 17                True
# 18                True
# 19                True

# %%
print("Nombre total d'identifiants défauts :", len(summary_default))
print("Identifiants détectés faulty :", summary_default["id_detected_faulty"].sum())
print("Pourcentage détecté :", round(summary_default["id_detected_faulty"].mean() * 100, 2), "%")
# Out:
# Nombre total d'identifiants défauts : 40
# Identifiants détectés faulty : 40
# Pourcentage détecté : 100.0 %

# %%
summary_default.sort_values(
    by="pct_windows_anormales",
    ascending=False
).head(5)
# Out:
#             i  nb_windows  nb_windows_anormales  pct_windows_anormales  \
# 17  KIQ82T2TF         142                    65              45.774648
# 6   9DI4D2S36         162                    61              37.654321
# 15  GAJOFQ4RL         205                    77              37.560976
# 32  VB8ITSU4T         189                    70              37.037037
# 31  V25U5JPDP         204                    75              36.764706
#
#     mean_log_likelihood  min_log_likelihood  max_anomaly_score  \
# 17           -34.265694         -146.827489         146.827489
# 6            -35.509386         -186.464472         186.464472
# 15           -32.007288         -163.641500         163.641500
# 32           -38.932269         -475.498307         475.498307
# 31           -43.003413         -404.870988         404.870988
#
#     mean_anomaly_score  id_detected_faulty
# 17           34.265694                True
# 6            35.509386                True
# 15           32.007288                True
# 32           38.932269                True
# 31           43.003413                True

# %%
plt.figure(figsize=(10, 5))

plt.hist(
    summary_default["pct_windows_anormales"],
    bins=30,
    alpha=0.7
)

plt.axvline(
    seuil_id,
    linestyle="--",
    label="Seuil identifiant"
)

plt.xlabel("% de fenêtres anormales")
plt.ylabel("Nombre d'identifiants défauts")
plt.title("Détection des défauts au niveau identifiant")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ---
# **Jour 2**
# ---

# %% [markdown]
# **Dataset 2**

# %%
fileTS2 = os.path.join(os.getcwd(), "pdfTimeSeries2.pkl".format(nSet))
pdfTS2 = pd.read_pickle(fileTS2)

# %%
pdfTS2
# Out:
#              u         y          i         e
# 0     0.000000 -0.056065  IQVYTIVZI -0.056065
# 1     0.000000  0.004750  IQVYTIVZI  0.004750
# 2     0.000000 -0.088224  IQVYTIVZI -0.088224
# 3     0.000000  0.103965  IQVYTIVZI  0.103965
# 4     0.000000 -0.105212  IQVYTIVZI -0.105212
# ...        ...       ...        ...       ...
# 1129 -1.499424 -1.521239  9DLVY2MTM -0.021815
# 1130 -1.499424 -1.464248  9DLVY2MTM  0.035176
# 1131 -1.499424 -1.528087  9DLVY2MTM -0.028663
# 1132 -1.499424 -1.509753  9DLVY2MTM -0.010329
# 1133 -1.499424 -1.396270  9DLVY2MTM  0.103154
#
# [187864 rows x 4 columns]

# %%
identifiant = "9DLVY2MTM"

pdfTS2_filtre = pdfTS2[pdfTS2["i"] == identifiant]

pdfTS2_filtre["u"].plot(label="Entrée")
pdfTS2_filtre["y"].plot(label="Sortie")


plt.xlabel("Indice de la ligne")
plt.ylabel("Valeur")
plt.title(f"Signaux pour i = {identifiant}")
plt.grid()
plt.legend()
plt.show()

# %%
fileEF2 = os.path.join(os.getcwd(), "pdfFeatures2.pkl".format(nSet))
pdfEF2 = pd.read_pickle(fileEF2)

# %%
pdfEF2
# Out:
#       e_Absolute energy e_Area under the curve e_Autocorrelation  \
# 0              0.059216               0.044443               1.0
# 1              0.044947               0.057335               1.0
# 2              0.043168               0.077023               1.0
# 3                0.0533               0.094651               1.0
# 4              0.067602                0.08591               1.0
# ...                 ...                    ...               ...
# 37364          0.029434               0.079779               1.0
# 37365          0.019913               0.056061               2.0
# 37366          0.026585               0.059124               2.0
# 37367          0.109663               0.140839               2.0
# 37368          0.098233               0.111209               2.0
#
#       e_Average power e_Centroid e_ECDF Percentile Count_0  \
# 0            0.032898   0.804866                       2.0
# 1             0.02497   0.595348                       2.0
# 2            0.023982   0.854625                       2.0
# 3            0.029611   0.786584                       2.0
# 4            0.037556   0.725336                       2.0
# ...               ...        ...                       ...
# 37364        0.016352   0.681912                       2.0
# 37365        0.011063     0.7887                       2.0
# 37366         0.01477   0.736369                       2.0
# 37367        0.060924   1.078961                       2.0
# 37368        0.054574   0.222157                       2.0
#
#       e_ECDF Percentile Count_1 e_ECDF Percentile_0 e_ECDF Percentile_1  \
# 0                           8.0           -0.088224            0.064545
# 1                           8.0           -0.068292            0.039978
# 2                           8.0           -0.068292            0.039978
# 3                           8.0           -0.098149            0.055082
# 4                           8.0           -0.113625            0.055082
# ...                         ...                 ...                 ...
# 37364                       8.0            0.010078            0.060526
# 37365                       8.0           -0.068776              0.0105
# 37366                       8.0           -0.068776             0.03031
# 37367                       8.0           -0.128093             0.03031
# 37368                       8.0           -0.128093           -0.015589
#
#       e_ECDF_0  ... y_Wavelet variance_1 y_Wavelet variance_2  \
# 0          0.1  ...             0.002374             0.002111
# 1          0.1  ...              0.00388             0.002158
# 2          0.1  ...             0.002692             0.001613
# 3          0.1  ...             0.010799              0.00719
# 4          0.1  ...             0.002384             0.002523
# ...        ...  ...                  ...                  ...
# 37364      0.1  ...             0.126341             0.151998
# 37365      0.1  ...             0.121303             0.184962
# 37366      0.1  ...             0.142319             0.152249
# 37367      0.1  ...             0.129391             0.218209
# 37368      0.1  ...             0.174399              0.15647
#
#       y_Wavelet variance_3 y_Wavelet variance_4 y_Wavelet variance_5  \
# 0                 0.001411             0.001006             0.000791
# 1                 0.001157             0.000822             0.000707
# 2                 0.001324              0.00114             0.001017
# 3                  0.00392              0.00242             0.001731
# 4                 0.002059             0.001659             0.001402
# ...                    ...                  ...                  ...
# 37364              0.23587             0.294779             0.319444
# 37365             0.284286             0.343689             0.364472
# 37366             0.233226             0.294619             0.321876
# 37367             0.327399             0.387338             0.405553
# 37368             0.240098             0.309878              0.34277
#
#       y_Wavelet variance_6 y_Wavelet variance_7 y_Wavelet variance_8  \
# 0                 0.000666             0.000583             0.000523
# 1                 0.000652             0.000613             0.000579
# 2                 0.000925             0.000849             0.000783
# 3                 0.001374             0.001161             0.001017
# 4                 0.001226             0.001096             0.000994
# ...                    ...                  ...                  ...
# 37364             0.322508             0.314392             0.301166
# 37365             0.363008             0.350744             0.333949
# 37366              0.32668             0.319572             0.306864
# 37367             0.400808             0.385341             0.365649
# 37368             0.350369             0.344249             0.331512
#
#       y_Zero crossing rate          i
# 0                      7.0  IQVYTIVZI
# 1                      5.0  IQVYTIVZI
# 2                      3.0  IQVYTIVZI
# 3                      3.0  IQVYTIVZI
# 4                      5.0  IQVYTIVZI
# ...                    ...        ...
# 37364                  0.0  9DLVY2MTM
# 37365                  0.0  9DLVY2MTM
# 37366                  0.0  9DLVY2MTM
# 37367                  0.0  9DLVY2MTM
# 37368                  0.0  9DLVY2MTM
#
# [37369 rows x 275 columns]

# %% [markdown]
# ---
# Perf Dataset 2
# ---

# %%
df_mix=pdfEF2.copy()

# ============================================================
# PARAMÈTRES
# ============================================================

ID_COL = "i"

N_PCA = 3

# Seuils que tu as observés avec l'outil du prof
NORMAL_ACCEPT_SCORE = 1
FAULT1_ACCEPT_SCORE = 1.15

# K-Means sur les défauts restants
N_D2_NEW_DEFECTS = 2

# KDE
BANDWIDTH_GRID = np.logspace(-1.5, 1.2, 25)

# Plus le quantile est bas, plus la KDE est permissive
KDE_THRESHOLD_Q_NORMAL = 0.01
KDE_THRESHOLD_Q_FAULT1 = 0.01

# Lissage KDE
BW_FACTOR_NORMAL = 1.8
BW_FACTOR_FAULT1 = 1.8

RANDOM_STATE = 42

# %%
# ============================================================
# DATASETS
# ============================================================

df_normal = pdfEF.copy()
df_fault1 = pdfEF_default.copy()
df_d2 = df_mix.copy()

print("Dataset0 normal :", df_normal.shape)
print("Dataset1 fault_1 :", df_fault1.shape)
print("Dataset2 :", df_d2.shape)
# Out:
# Dataset0 normal : (49316, 275)
# Dataset1 fault_1 : (9983, 275)
# Dataset2 : (37369, 275)

# %%
# ============================================================
# FEATURES COMMUNES
# ============================================================

cols_to_exclude = [
    ID_COL,
    "type", "label", "target", "classe", "class",
    "final_label", "cluster", "label_known"
]

feature_cols = [
    col for col in df_d2.columns
    if col not in cols_to_exclude
    and col in df_normal.columns
    and col in df_fault1.columns
]

print("Nombre de features communes :", len(feature_cols))

if len(feature_cols) == 0:
    raise ValueError("Aucune feature commune trouvée.")
# Out:
# Nombre de features communes : 274

# %%
# ============================================================
# AGRÉGATION : 1 LIGNE PAR IDENTIFIANT
# ============================================================

def prepare_agg(df, feature_cols, id_col):
    temp = df[[id_col] + feature_cols].copy()
    
    for col in feature_cols:
        temp[col] = (
            temp[col]
            .astype(str)
            .str.replace(",", ".", regex=False)
            .str.replace(" ", "", regex=False)
        )
        temp[col] = pd.to_numeric(temp[col], errors="coerce")
    
    temp = temp.replace([np.inf, -np.inf], np.nan)
    
    df_agg = temp.groupby(id_col)[feature_cols].mean().reset_index()
    
    return df_agg


normal_agg = prepare_agg(df_normal, feature_cols, ID_COL)
fault1_agg = prepare_agg(df_fault1, feature_cols, ID_COL)
d2_agg = prepare_agg(df_d2, feature_cols, ID_COL)

print("Normal agrégé :", normal_agg.shape)
print("Fault 1 agrégé :", fault1_agg.shape)
print("Dataset2 agrégé :", d2_agg.shape)

print("Identifiants dataset2 :", d2_agg[ID_COL].nunique())
# Out:
# Normal agrégé : (200, 275)
# Fault 1 agrégé : (40, 275)
# Dataset2 agrégé : (150, 275)
# Identifiants dataset2 : 150

# %%
# ============================================================
# PRÉTRAITEMENT COMMUN
# ============================================================
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
X_fit = pd.concat(
    [
        normal_agg[feature_cols],
        fault1_agg[feature_cols],
        d2_agg[feature_cols]
    ],
    ignore_index=True
)

X_normal = normal_agg[feature_cols].copy()
X_fault1 = fault1_agg[feature_cols].copy()
X_d2 = d2_agg[feature_cols].copy()

# Inf → NaN
X_fit = X_fit.replace([np.inf, -np.inf], np.nan)
X_normal = X_normal.replace([np.inf, -np.inf], np.nan)
X_fault1 = X_fault1.replace([np.inf, -np.inf], np.nan)
X_d2 = X_d2.replace([np.inf, -np.inf], np.nan)

# Supprimer colonnes entièrement vides
cols_all_nan = X_fit.columns[X_fit.isna().all()].tolist()

if len(cols_all_nan) > 0:
    print("Colonnes supprimées car entièrement NaN :", cols_all_nan)
    X_fit = X_fit.drop(columns=cols_all_nan)
    X_normal = X_normal.drop(columns=cols_all_nan)
    X_fault1 = X_fault1.drop(columns=cols_all_nan)
    X_d2 = X_d2.drop(columns=cols_all_nan)

# Imputation
imputer = SimpleImputer(strategy="median")

X_fit_imp = imputer.fit_transform(X_fit)
X_normal_imp = imputer.transform(X_normal)
X_fault1_imp = imputer.transform(X_fault1)
X_d2_imp = imputer.transform(X_d2)

cols_after_nan = X_fit.columns

X_fit_imp = pd.DataFrame(X_fit_imp, columns=cols_after_nan)
X_normal_imp = pd.DataFrame(X_normal_imp, columns=cols_after_nan)
X_fault1_imp = pd.DataFrame(X_fault1_imp, columns=cols_after_nan)
X_d2_imp = pd.DataFrame(X_d2_imp, columns=cols_after_nan)

# Suppression colonnes constantes
selector = VarianceThreshold(threshold=0)

X_fit_var = selector.fit_transform(X_fit_imp)
X_normal_var = selector.transform(X_normal_imp)
X_fault1_var = selector.transform(X_fault1_imp)
X_d2_var = selector.transform(X_d2_imp)

selected_cols = cols_after_nan[selector.get_support()]

X_fit_var = pd.DataFrame(X_fit_var, columns=selected_cols)
X_normal_var = pd.DataFrame(X_normal_var, columns=selected_cols)
X_fault1_var = pd.DataFrame(X_fault1_var, columns=selected_cols)
X_d2_var = pd.DataFrame(X_d2_var, columns=selected_cols)

print("Features après nettoyage :", X_fit_var.shape[1])

# Clipping des valeurs extrêmes
lower = X_fit_var.quantile(0.01)
upper = X_fit_var.quantile(0.99)

X_fit_clip = X_fit_var.clip(lower=lower, upper=upper, axis=1)
X_normal_clip = X_normal_var.clip(lower=lower, upper=upper, axis=1)
X_fault1_clip = X_fault1_var.clip(lower=lower, upper=upper, axis=1)
X_d2_clip = X_d2_var.clip(lower=lower, upper=upper, axis=1)

# Scaling
scaler = RobustScaler()

X_fit_scaled = scaler.fit_transform(X_fit_clip)
X_normal_scaled = scaler.transform(X_normal_clip)
X_fault1_scaled = scaler.transform(X_fault1_clip)
X_d2_scaled = scaler.transform(X_d2_clip)

X_fit_scaled = np.nan_to_num(X_fit_scaled, nan=0.0, posinf=0.0, neginf=0.0)
X_normal_scaled = np.nan_to_num(X_normal_scaled, nan=0.0, posinf=0.0, neginf=0.0)
X_fault1_scaled = np.nan_to_num(X_fault1_scaled, nan=0.0, posinf=0.0, neginf=0.0)
X_d2_scaled = np.nan_to_num(X_d2_scaled, nan=0.0, posinf=0.0, neginf=0.0)

# PCA commune
n_components = min(N_PCA, X_fit_scaled.shape[1], X_fit_scaled.shape[0] - 1)

pca = PCA(n_components=n_components, random_state=RANDOM_STATE)

X_fit_red = pca.fit_transform(X_fit_scaled)
X_normal_red = pca.transform(X_normal_scaled)
X_fault1_red = pca.transform(X_fault1_scaled)
X_d2_red = pca.transform(X_d2_scaled)

print("Nombre de composantes PCA :", n_components)
print("Variance expliquée totale :", round(pca.explained_variance_ratio_.sum(), 4))
# Out:
# Features après nettoyage : 262
# Nombre de composantes PCA : 3
# Variance expliquée totale : 0.6564
# c:\Users\louay\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1904: RuntimeWarning: overflow encountered in multiply
#   sqr = np.multiply(arr, arr, out=arr, where=where)

# %%
# ============================================================
# FONCTION KDE
# ============================================================

def fit_kde_model(X_class, label, threshold_q, bandwidth_factor=1.0):
    X_class = np.asarray(X_class)
    
    if len(X_class) < 3:
        raise ValueError(f"Pas assez de points pour KDE sur {label}")
    
    cv = min(5, len(X_class))
    
    grid = GridSearchCV(
        KernelDensity(kernel="gaussian"),
        {"bandwidth": BANDWIDTH_GRID},
        cv=cv
    )
    
    grid.fit(X_class)
    
    best_bw = grid.best_params_["bandwidth"]
    final_bw = best_bw * bandwidth_factor
    
    kde = KernelDensity(
        kernel="gaussian",
        bandwidth=final_bw
    )
    
    kde.fit(X_class)
    
    log_density_train = kde.score_samples(X_class)
    threshold = np.quantile(log_density_train, threshold_q)
    
    print(label)
    print("  nb points :", len(X_class))
    print("  bandwidth CV :", round(best_bw, 4))
    print("  bandwidth final :", round(final_bw, 4))
    print("  seuil KDE :", round(threshold, 4))
    
    return {
        "label": label,
        "kde": kde,
        "threshold": threshold,
        "threshold_q": threshold_q,
        "bandwidth": final_bw
    }

# %%
def kde_score(model, X):
    """
    Score = log_density - seuil KDE.
    Plus le score est haut, plus le point ressemble à la classe.
    """
    log_density = model["kde"].score_samples(X)
    score = log_density - model["threshold"]
    return log_density, score

# %%
# ============================================================
# KDE NORMAL + FAULT_1
# ============================================================

kde_normal = fit_kde_model(
    X_normal_red,
    label="normal",
    threshold_q=KDE_THRESHOLD_Q_NORMAL,
    bandwidth_factor=BW_FACTOR_NORMAL
)

kde_fault1 = fit_kde_model(
    X_fault1_red,
    label="fault_1",
    threshold_q=KDE_THRESHOLD_Q_FAULT1,
    bandwidth_factor=BW_FACTOR_FAULT1
)
# Out:
# normal
#   nb points : 200
#   bandwidth CV : 1.1885
#   bandwidth final : 2.1393
#   seuil KDE : -9.544
# fault_1
#   nb points : 40
#   bandwidth CV : 2.5852
#   bandwidth final : 4.6534
#   seuil KDE : -10.1214

# %%
# ============================================================
# SEUILS FORTS KDE
# ============================================================

STRONG_NORMAL_SCORE = 2.5
STRONG_FAULT1_SCORE = 2.0

df_d2_pred["strong_label"] = "unknown"

# Si le score normal est très élevé
mask_strong_normal = (
    (df_d2_pred["kde_score_normal"] >= STRONG_NORMAL_SCORE) &
    (df_d2_pred["kde_score_normal"] >= df_d2_pred["kde_score_fault_1"])
)

df_d2_pred.loc[mask_strong_normal, "strong_label"] = "normal"

# Si le score fault_1 est très élevé
mask_strong_fault1 = (
    (df_d2_pred["kde_score_fault_1"] >= STRONG_FAULT1_SCORE) &
    (df_d2_pred["kde_score_fault_1"] > df_d2_pred["kde_score_normal"])
)

df_d2_pred.loc[mask_strong_fault1, "strong_label"] = "fault_1"

print("Points très sûrs selon KDE :")
print(df_d2_pred["strong_label"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 8
#       5 STRONG_NORMAL_SCORE = 2.5
#       6 STRONG_FAULT1_SCORE = 2.0
# ----> 8 df_d2_pred["strong_label"] = "unknown"
#      10 # Si le score normal est très élevé
#      11 mask_strong_normal = (
#      12     (df_d2_pred["kde_score_normal"] >= STRONG_NORMAL_SCORE) &
#      13     (df_d2_pred["kde_score_normal"] >= df_d2_pred["kde_score_fault_1"])
#      14 )
#
# NameError: name 'df_d2_pred' is not defined

# %%
# ============================================================
# K-MEANS k=4 SUR TOUT LE DATASET2
# ============================================================

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

K_D2 = 4

kmeans_d2_k4 = KMeans(
    n_clusters=K_D2,
    random_state=42,
    n_init=50
)

clusters_k4 = kmeans_d2_k4.fit_predict(X_d2_red)

df_d2_pred["cluster_k4"] = clusters_k4

print("Répartition des clusters K-Means :")
print(df_d2_pred["cluster_k4"].value_counts().sort_index())

sil = silhouette_score(X_d2_red, clusters_k4)
print("Silhouette k=4 :", round(sil, 4))

# %%
# ============================================================
# ANALYSE DES CLUSTERS
# ============================================================

cluster_analysis = []

for cluster_id in sorted(df_d2_pred["cluster_k4"].unique()):
    subset = df_d2_pred[df_d2_pred["cluster_k4"] == cluster_id]
    
    cluster_analysis.append({
        "cluster": cluster_id,
        "taille": len(subset),
        "strong_normal": (subset["strong_label"] == "normal").sum(),
        "strong_fault1": (subset["strong_label"] == "fault_1").sum(),
        "mean_score_normal": subset["kde_score_normal"].mean(),
        "max_score_normal": subset["kde_score_normal"].max(),
        "mean_score_fault1": subset["kde_score_fault_1"].mean(),
        "max_score_fault1": subset["kde_score_fault_1"].max()
    })

df_cluster_analysis = pd.DataFrame(cluster_analysis)

df_cluster_analysis

# %%
# ============================================================
# ASSOCIATION DES CLUSTERS AUX CLASSES
# ============================================================

available_clusters = set(df_cluster_analysis["cluster"])

# 1. Cluster normal :
# priorité au nombre de strong_normal, puis au score normal moyen
normal_cluster = (
    df_cluster_analysis
    .sort_values(
        by=["strong_normal", "mean_score_normal"],
        ascending=[False, False]
    )
    .iloc[0]["cluster"]
)

available_clusters.remove(normal_cluster)

# 2. Cluster fault_1 :
# parmi les clusters restants, priorité au nombre de strong_fault1,
# puis au score fault1 moyen
fault1_cluster = (
    df_cluster_analysis[df_cluster_analysis["cluster"].isin(available_clusters)]
    .sort_values(
        by=["strong_fault1", "mean_score_fault1"],
        ascending=[False, False]
    )
    .iloc[0]["cluster"]
)

available_clusters.remove(fault1_cluster)

# 3. Les deux clusters restants = nouveaux défauts du dataset2
remaining_clusters = sorted(list(available_clusters))

cluster_to_label = {
    normal_cluster: "normal",
    fault1_cluster: "fault_1",
    remaining_clusters[0]: "d2_defect_0",
    remaining_clusters[1]: "d2_defect_1"
}

print("Mapping cluster → classe :")
print(cluster_to_label)

# %%
# ============================================================
# ATTRIBUTION FINALE DATASET2
# ============================================================

df_d2_pred["final_label"] = df_d2_pred["cluster_k4"].map(cluster_to_label)

summary_d2 = df_d2_pred["final_label"].value_counts().reset_index()
summary_d2.columns = ["classe_predite", "nombre_identifiants"]

print(summary_d2)
print("\nTotal identifiants classifiés :", summary_d2["nombre_identifiants"].sum())

print("\nObjectif attendu :")
print("normal       ≈ 90")
print("fault_1      ≈ 10")
print("d2_defect_0  ≈ 25")
print("d2_defect_1  ≈ 25")

# %%
# ============================================================
# TABLE FINALE DATASET2
# ============================================================

df_table_finale_d2 = df_d2_pred[
    [
        ID_COL,
        "kde_score_normal",
        "kde_score_fault_1",
        "strong_label",
        "cluster_k4",
        "final_label"
    ]
].copy()

df_table_finale_d2 = df_table_finale_d2.rename(columns={
    ID_COL: "identifiant",
    "kde_score_normal": "score_normal",
    "kde_score_fault_1": "score_fault_1",
    "strong_label": "decision_kde_forte",
    "cluster_k4": "cluster_kmeans",
    "final_label": "decision_finale"
})

df_table_finale_d2 = df_table_finale_d2.sort_values(
    by=["decision_finale", "cluster_kmeans", "score_normal"],
    ascending=[True, True, False]
).reset_index(drop=True)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

df_table_finale_d2

# %%
# ============================================================
# ÉVALUATION DATASET2 AVEC pdfLabel2
# ============================================================

from itertools import permutations
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, balanced_accuracy_score

TRUE_LABEL_COL = "d"

df_eval_d2 = df_d2_pred[
    [
        ID_COL,
        "final_label",
        "kde_score_normal",
        "kde_score_fault_1",
        "strong_label",
        "cluster_k4"
    ]
].merge(
    pdfLabel2[[ID_COL, TRUE_LABEL_COL]],
    on=ID_COL,
    how="left"
).rename(columns={TRUE_LABEL_COL: "true_label"})

df_eval_d2["true_label"] = df_eval_d2["true_label"].astype(int)

# Mapping fixe :
# normal = 0
# fault_1 = 1
# d2_defect_0 / d2_defect_1 = soit 4 soit 5
base_mapping = {
    "normal": 0,
    "fault_1": 1
}

cluster_labels = ["d2_defect_0", "d2_defect_1"]
true_defect_labels = [4, 5]

best_mapping = None
best_score = -1

for perm in permutations(true_defect_labels):
    current_mapping = base_mapping.copy()
    current_mapping[cluster_labels[0]] = perm[0]
    current_mapping[cluster_labels[1]] = perm[1]
    
    temp_pred = df_eval_d2["final_label"].map(current_mapping)
    score = (temp_pred == df_eval_d2["true_label"]).sum()
    
    if score > best_score:
        best_score = score
        best_mapping = current_mapping

print("Meilleur mapping final_label → vrai label :")
print(best_mapping)

df_eval_d2["pred_label"] = df_eval_d2["final_label"].map(best_mapping)

labels_order = [0, 1, 4, 5]

conf_matrix_d2 = pd.DataFrame(
    confusion_matrix(
        df_eval_d2["true_label"],
        df_eval_d2["pred_label"],
        labels=labels_order
    ),
    index=[f"vrai_{x}" for x in labels_order],
    columns=[f"pred_{x}" for x in labels_order]
)

display(conf_matrix_d2)

print("Accuracy :", round(accuracy_score(df_eval_d2["true_label"], df_eval_d2["pred_label"]), 4))
print("Balanced accuracy :", round(balanced_accuracy_score(df_eval_d2["true_label"], df_eval_d2["pred_label"]), 4))

print(
    classification_report(
        df_eval_d2["true_label"],
        df_eval_d2["pred_label"],
        labels=labels_order,
        target_names=["normal", "fault_1", "defaut_4", "defaut_5"],
        zero_division=0
    )
)

# %% [markdown]
# ---
# Confusion matrix dataset2
# ---

# %%
nSet = 0
filelabel2 = os.path.join(os.getcwd(), "pdfLabel2.pkl".format(nSet))
pdflabel2 = pd.read_pickle(filelabel2)

# %%
import pandas as pd
import numpy as np
from itertools import permutations
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, balanced_accuracy_score

ID_COL = "i"
TRUE_LABEL_COL = "d"

# %%
# ============================================================
# 1. Fusion prédictions + vrais labels
# ============================================================

df_eval_d2 = df_d2_pred[
    [
        ID_COL,
        "final_label",
        "label_known",
        "kde_score_normal",
        "kde_score_fault_1"
    ]
].copy()

df_eval_d2 = df_eval_d2.merge(
    pdflabel2[[ID_COL, TRUE_LABEL_COL]],
    on=ID_COL,
    how="left"
)

df_eval_d2 = df_eval_d2.rename(columns={TRUE_LABEL_COL: "true_label"})

# Sécurité : convertir les vrais labels en int
df_eval_d2["true_label"] = df_eval_d2["true_label"].astype(int)

print("Nombre de lignes :", len(df_eval_d2))
print("Labels manquants :", df_eval_d2["true_label"].isna().sum())

print("\nRépartition réelle :")
print(df_eval_d2["true_label"].value_counts().sort_index())

print("\nRépartition prédite :")
print(df_eval_d2["final_label"].value_counts())
# Out:
# Nombre de lignes : 150
# Labels manquants : 0
#
# Répartition réelle :
# true_label
# 0    90
# 1    10
# 4    25
# 5    25
# Name: count, dtype: int64
#
# Répartition prédite :
# final_label
# normal         86
# d2_defect_0    32
# d2_defect_1    24
# fault_1         8
# Name: count, dtype: int64

# %%
# ============================================================
# 2. Mapping automatique des clusters d2_defect_0 / d2_defect_1
# ============================================================

# Labels fixes
base_mapping = {
    "normal": 0,
    "fault_1": 1
}

# Clusters à mapper automatiquement vers 4 et 5
cluster_labels = ["d2_defect_0", "d2_defect_1"]
true_defect_labels = [4, 5]

best_mapping = None
best_score = -1

# On teste les deux possibilités :
# d2_defect_0 -> 4 et d2_defect_1 -> 5
# ou l'inverse
for perm in permutations(true_defect_labels):
    
    current_mapping = base_mapping.copy()
    current_mapping[cluster_labels[0]] = perm[0]
    current_mapping[cluster_labels[1]] = perm[1]
    
    temp_pred = df_eval_d2["final_label"].map(current_mapping)
    
    score = (temp_pred == df_eval_d2["true_label"]).sum()
    
    if score > best_score:
        best_score = score
        best_mapping = current_mapping

print("Meilleur mapping trouvé :")
print(best_mapping)

df_eval_d2["pred_label"] = df_eval_d2["final_label"].map(best_mapping)

print("\nRépartition prédite après mapping :")
print(df_eval_d2["pred_label"].value_counts().sort_index())
# Out:
# Meilleur mapping trouvé :
# {'normal': 0, 'fault_1': 1, 'd2_defect_0': 5, 'd2_defect_1': 4}
#
# Répartition prédite après mapping :
# pred_label
# 0    86
# 1     8
# 4    24
# 5    32
# Name: count, dtype: int64

# %%
# ============================================================
# 3. Matrice de confusion
# ============================================================

labels_order = [0, 1, 4, 5]

conf_matrix = pd.DataFrame(
    confusion_matrix(
        df_eval_d2["true_label"],
        df_eval_d2["pred_label"],
        labels=labels_order
    ),
    index=[f"vrai_{x}" for x in labels_order],
    columns=[f"pred_{x}" for x in labels_order]
)

conf_matrix
# Out:
#         pred_0  pred_1  pred_4  pred_5
# vrai_0      75       0       0      15
# vrai_1       0       7       0       3
# vrai_4       0       0      24       1
# vrai_5      11       1       0      13

# %%
# ============================================================
# 4. Scores de performance
# ============================================================

accuracy = accuracy_score(df_eval_d2["true_label"], df_eval_d2["pred_label"])
balanced_acc = balanced_accuracy_score(df_eval_d2["true_label"], df_eval_d2["pred_label"])

print("Accuracy globale :", round(accuracy, 4))
print("Balanced accuracy :", round(balanced_acc, 4))

print("\nRapport détaillé :")
print(
    classification_report(
        df_eval_d2["true_label"],
        df_eval_d2["pred_label"],
        labels=labels_order,
        target_names=["normal", "fault_1", "defaut_4", "defaut_5"],
        zero_division=0
    )
)
# Out:
# Accuracy globale : 0.7933
# Balanced accuracy : 0.7533
#
# Rapport détaillé :
#               precision    recall  f1-score   support
#
#       normal       0.87      0.83      0.85        90
#      fault_1       0.88      0.70      0.78        10
#     defaut_4       1.00      0.96      0.98        25
#     defaut_5       0.41      0.52      0.46        25
#
#     accuracy                           0.79       150
#    macro avg       0.79      0.75      0.77       150
# weighted avg       0.82      0.79      0.80       150

# %%
# ============================================================
# 5. Résumé vrai vs prédit
# ============================================================

summary_perf_d2 = pd.DataFrame({
    "classe": labels_order,
    "nombre_reel": [
        (df_eval_d2["true_label"] == label).sum()
        for label in labels_order
    ],
    "nombre_predit": [
        (df_eval_d2["pred_label"] == label).sum()
        for label in labels_order
    ],
    "bien_classes": [
        ((df_eval_d2["true_label"] == label) & (df_eval_d2["pred_label"] == label)).sum()
        for label in labels_order
    ]
})

summary_perf_d2["taux_reussite_classe"] = (
    summary_perf_d2["bien_classes"] / summary_perf_d2["nombre_reel"]
).round(4)

summary_perf_d2
# Out:
#    classe  nombre_reel  nombre_predit  bien_classes  taux_reussite_classe
# 0       0           90             86            75                0.8333
# 1       1           10              8             7                0.7000
# 2       4           25             24            24                0.9600
# 3       5           25             32            13                0.5200

# %%
# ============================================================
# 6. Table des erreurs avec identifiants
# ============================================================

df_errors_d2 = df_eval_d2[
    df_eval_d2["true_label"] != df_eval_d2["pred_label"]
].copy()

df_errors_d2 = df_errors_d2[
    [
        ID_COL,
        "true_label",
        "pred_label",
        "final_label",
        "label_known",
        "kde_score_normal",
        "kde_score_fault_1"
    ]
].sort_values(
    by=["true_label", "pred_label", ID_COL]
).reset_index(drop=True)

print("Nombre d'erreurs :", len(df_errors_d2))

df_errors_d2
# Out:
# Nombre d'erreurs : 31
#             i  true_label  pred_label  final_label label_known  \
# 0   35X6YWYM3           0           5  d2_defect_0     unknown
# 1   4398XY0AP           0           5  d2_defect_0     unknown
# 2   DDGLDBW6B           0           5  d2_defect_0     unknown
# 3   I4ZQEMPTZ           0           5  d2_defect_0     unknown
# 4   L8XNECEZQ           0           5  d2_defect_0     unknown
# 5   LBU6LJA0G           0           5  d2_defect_0     unknown
# 6   LF05H3AZV           0           5  d2_defect_0     unknown
# 7   LFT7BCKDG           0           5  d2_defect_0     unknown
# 8   MEZRKZMRO           0           5  d2_defect_0     unknown
# 9   N30VVGTA0           0           5  d2_defect_0     unknown
# 10  R52PUF5PI           0           5  d2_defect_0     unknown
# 11  W11XA8KQ9           0           5  d2_defect_0     unknown
# 12  YPYTCNQ0U           0           5  d2_defect_0     unknown
# 13  ZI93DSRKV           0           5  d2_defect_0     unknown
# 14  ZOXCH5OEH           0           5  d2_defect_0     unknown
# 15  G2XKX4KBG           1           5  d2_defect_0     unknown
# 16  SYRAKGYPD           1           5  d2_defect_0     unknown
# 17  Y2R1NGXRF           1           5  d2_defect_0     unknown
# 18  1DACI9FCQ           4           5  d2_defect_0     unknown
# 19  1ZJHC20K3           5           0       normal      normal
# 20  3I1JGEBY8           5           0       normal      normal
# 21  3VHFQ5US3           5           0       normal      normal
# 22  4TUTPCDY5           5           0       normal      normal
# 23  9DLVY2MTM           5           0       normal      normal
# 24  BTWCJPLCV           5           0       normal      normal
# 25  CD6SR78M0           5           0       normal      normal
# 26  OHKGGSAJT           5           0       normal      normal
# 27  R9FBHNH69           5           0       normal      normal
# 28  U5TGZLKRS           5           0       normal      normal
# 29  XVK7TGGEF           5           0       normal      normal
# 30  98LY7JJGA           5           1      fault_1     fault_1
#
#     kde_score_normal  kde_score_fault_1
# 0           1.317656          -5.920270
# 1           0.121221           1.014070
# 2           0.831073          -1.263434
# 3           1.550680          -0.035880
# 4           1.597128          -3.945041
# 5           1.069044          -0.968620
# 6           0.878300          -3.441184
# 7           1.058532           0.582117
# 8           0.929948          -0.798710
# 9           0.287808          -3.918895
# 10          0.769020          -7.051269
# 11          0.598273           0.697889
# 12          1.035229           0.888961
# 13         -0.037700          -3.662223
# 14          0.865334          -0.394744
# 15        -27.578479           1.231803
# 16        -22.342570           1.672384
# 17         -0.682777           1.659487
# 18        -11.791825          -5.518602
# 19          2.255624          -1.739449
# 20          2.207771          -3.098713
# 21          2.005703          -0.007547
# 22          1.910871           1.106312
# 23          1.816147           0.975201
# 24          1.737581          -1.879394
# 25          2.734349          -1.699814
# 26          2.848296          -0.474810
# 27          2.152697           1.090534
# 28          2.266522          -3.086702
# 29          2.405472           0.293027
# 30         -0.674115           2.145874

# %% [markdown]
# ---
# **Amélioration jour 3 sur le dataset 3**
# ---

# %%
nSet = 0
fileTS3 = os.path.join(os.getcwd(), "pdfTimeSeries3.pkl".format(nSet))
pdfTS3 = pd.read_pickle(fileTS3)

# %%
fileEF3 = os.path.join(os.getcwd(), "pdfFeatures3.pkl".format(nSet))
pdfEF3 = pd.read_pickle(fileEF3)

# %%
# ============================================================
# CLASSIFICATION DATASET3 AVEC KDE + K-MEANS
# ============================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.decomposition import PCA
from sklearn.neighbors import KernelDensity
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ---
# Paramètres Dataset3
# ---

# %%
ID_COL = "i"

# KDE en faible dimension
N_PCA = 3

N_D2_DEFECTS = 2
N_D3_NEW_DEFECTS = 3

# Seuils plus permissifs pour reconnaître normal et fault_1
KDE_THRESHOLD_Q_NORMAL = 0.01
KDE_THRESHOLD_Q_FAULT1 = 0.01

# Pour les défauts appris du dataset2, on reste plus strict
KDE_THRESHOLD_Q_D2 = 0.20

# Marges : négatif = plus permissif
MARGIN_NORMAL = -0.50
MARGIN_FAULT1 = -0.50
MARGIN_D2_DEFECT = 0.15

# Seuils d'acceptation observés manuellement
ACCEPT_SCORE_BY_LABEL = {
    "normal": 1.6,
    "fault_1": 1.90,
    
    # Pour les défauts appris du dataset2, on garde un seuil neutre pour l'instant
    "d2_defect_0": 1,
    "d2_defect_1": -0.5
}

# Grille de bandwidth KDE
BANDWIDTH_GRID = np.logspace(-1.5, 1.2, 25)

# Facteur pour lisser un peu plus les KDE normal/fault_1
BW_FACTOR_NORMAL = 1.8
BW_FACTOR_FAULT1 = 1.8
BW_FACTOR_D2 = 1.2

RANDOM_STATE = 42

# %%
# ============================================================
# 2. DÉCLARATION DES DATASETS
# ============================================================

df_normal = pdfEF.copy()          # dataset0 : normal
df_fault1 = pdfEF_default.copy()   # dataset1 : défaut 1
df_d2 = pdfEF2.copy()             # dataset2 : mélange avec nouveaux défauts
df_d3 = pdfEF3.copy()             # dataset3 : à classifier

print("Dataset0 normal :", df_normal.shape)
print("Dataset1 défaut 1 :", df_fault1.shape)
print("Dataset2 :", df_d2.shape)
print("Dataset3 :", df_d3.shape)
# Out:
# Dataset0 normal : (49316, 275)
# Dataset1 défaut 1 : (9983, 275)
# Dataset2 : (37369, 275)
# Dataset3 : (39533, 275)

# %%
# ============================================================
# 3. FEATURES COMMUNES
# ============================================================

cols_to_exclude = [
    ID_COL,
    "type", "label", "target", "classe", "class",
    "final_label", "cluster", "label_known"
]

feature_cols = [
    col for col in df_d3.columns
    if col not in cols_to_exclude
    and col in df_normal.columns
    and col in df_fault1.columns
    and col in df_d2.columns
]

print("Nombre de features communes :", len(feature_cols))

if len(feature_cols) == 0:
    raise ValueError("Aucune feature commune trouvée. Vérifie les noms de colonnes.")
# Out:
# Nombre de features communes : 274

# %%
# ============================================================
# 4. AGRÉGATION DES FENÊTRES : 1 LIGNE PAR IDENTIFIANT
# ============================================================

def prepare_agg(df, feature_cols, id_col):
    temp = df[[id_col] + feature_cols].copy()
    
    for col in feature_cols:
        temp[col] = (
            temp[col]
            .astype(str)
            .str.replace(",", ".", regex=False)
            .str.replace(" ", "", regex=False)
        )
        temp[col] = pd.to_numeric(temp[col], errors="coerce")
    
    temp = temp.replace([np.inf, -np.inf], np.nan)
    
    df_agg = temp.groupby(id_col)[feature_cols].mean().reset_index()
    
    return df_agg


normal_agg = prepare_agg(df_normal, feature_cols, ID_COL)
fault1_agg = prepare_agg(df_fault1, feature_cols, ID_COL)
d2_agg = prepare_agg(df_d2, feature_cols, ID_COL)
d3_agg = prepare_agg(df_d3, feature_cols, ID_COL)

print("Normal agrégé :", normal_agg.shape)
print("Fault 1 agrégé :", fault1_agg.shape)
print("Dataset2 agrégé :", d2_agg.shape)
print("Dataset3 agrégé :", d3_agg.shape)

print("Identifiants dataset3 :", d3_agg[ID_COL].nunique())
# Out:
# Normal agrégé : (200, 275)
# Fault 1 agrégé : (40, 275)
# Dataset2 agrégé : (150, 275)
# Dataset3 agrégé : (160, 275)
# Identifiants dataset3 : 160

# %%
# ============================================================
# 5. PRÉTRAITEMENT COMMUN : IMPUTER + SCALER + PCA
# La PCA est apprise sur dataset0 + dataset1 + dataset2.
# Dataset3 est seulement transformé.
# ============================================================

X_fit = pd.concat(
    [
        normal_agg[feature_cols],
        fault1_agg[feature_cols],
        d2_agg[feature_cols]
    ],
    ignore_index=True
)

X_normal = normal_agg[feature_cols].copy()
X_fault1 = fault1_agg[feature_cols].copy()
X_d2 = d2_agg[feature_cols].copy()
X_d3 = d3_agg[feature_cols].copy()

# Remplacer infinis par NaN
X_fit = X_fit.replace([np.inf, -np.inf], np.nan)
X_normal = X_normal.replace([np.inf, -np.inf], np.nan)
X_fault1 = X_fault1.replace([np.inf, -np.inf], np.nan)
X_d2 = X_d2.replace([np.inf, -np.inf], np.nan)
X_d3 = X_d3.replace([np.inf, -np.inf], np.nan)

# Supprimer colonnes entièrement vides dans le fit
cols_all_nan = X_fit.columns[X_fit.isna().all()].tolist()

if len(cols_all_nan) > 0:
    print("Colonnes supprimées car entièrement NaN :", cols_all_nan)
    X_fit = X_fit.drop(columns=cols_all_nan)
    X_normal = X_normal.drop(columns=cols_all_nan)
    X_fault1 = X_fault1.drop(columns=cols_all_nan)
    X_d2 = X_d2.drop(columns=cols_all_nan)
    X_d3 = X_d3.drop(columns=cols_all_nan)

# Imputation
imputer = SimpleImputer(strategy="median")

X_fit_imp = imputer.fit_transform(X_fit)
X_normal_imp = imputer.transform(X_normal)
X_fault1_imp = imputer.transform(X_fault1)
X_d2_imp = imputer.transform(X_d2)
X_d3_imp = imputer.transform(X_d3)

cols_after_nan = X_fit.columns

X_fit_imp = pd.DataFrame(X_fit_imp, columns=cols_after_nan)
X_normal_imp = pd.DataFrame(X_normal_imp, columns=cols_after_nan)
X_fault1_imp = pd.DataFrame(X_fault1_imp, columns=cols_after_nan)
X_d2_imp = pd.DataFrame(X_d2_imp, columns=cols_after_nan)
X_d3_imp = pd.DataFrame(X_d3_imp, columns=cols_after_nan)

# Suppression colonnes constantes
selector = VarianceThreshold(threshold=0)

X_fit_var = selector.fit_transform(X_fit_imp)
X_normal_var = selector.transform(X_normal_imp)
X_fault1_var = selector.transform(X_fault1_imp)
X_d2_var = selector.transform(X_d2_imp)
X_d3_var = selector.transform(X_d3_imp)

selected_cols = cols_after_nan[selector.get_support()]

X_fit_var = pd.DataFrame(X_fit_var, columns=selected_cols)
X_normal_var = pd.DataFrame(X_normal_var, columns=selected_cols)
X_fault1_var = pd.DataFrame(X_fault1_var, columns=selected_cols)
X_d2_var = pd.DataFrame(X_d2_var, columns=selected_cols)
X_d3_var = pd.DataFrame(X_d3_var, columns=selected_cols)

print("Features après nettoyage :", X_fit_var.shape[1])

# Limitation des valeurs extrêmes selon le fit
lower = X_fit_var.quantile(0.01)
upper = X_fit_var.quantile(0.99)

X_fit_clip = X_fit_var.clip(lower=lower, upper=upper, axis=1)
X_normal_clip = X_normal_var.clip(lower=lower, upper=upper, axis=1)
X_fault1_clip = X_fault1_var.clip(lower=lower, upper=upper, axis=1)
X_d2_clip = X_d2_var.clip(lower=lower, upper=upper, axis=1)
X_d3_clip = X_d3_var.clip(lower=lower, upper=upper, axis=1)

# Scaling robuste
scaler = RobustScaler()

X_fit_scaled = scaler.fit_transform(X_fit_clip)
X_normal_scaled = scaler.transform(X_normal_clip)
X_fault1_scaled = scaler.transform(X_fault1_clip)
X_d2_scaled = scaler.transform(X_d2_clip)
X_d3_scaled = scaler.transform(X_d3_clip)

X_fit_scaled = np.nan_to_num(X_fit_scaled, nan=0.0, posinf=0.0, neginf=0.0)
X_normal_scaled = np.nan_to_num(X_normal_scaled, nan=0.0, posinf=0.0, neginf=0.0)
X_fault1_scaled = np.nan_to_num(X_fault1_scaled, nan=0.0, posinf=0.0, neginf=0.0)
X_d2_scaled = np.nan_to_num(X_d2_scaled, nan=0.0, posinf=0.0, neginf=0.0)
X_d3_scaled = np.nan_to_num(X_d3_scaled, nan=0.0, posinf=0.0, neginf=0.0)

# PCA commune
n_components = min(N_PCA, X_fit_scaled.shape[1], X_fit_scaled.shape[0] - 1)

pca = PCA(n_components=n_components, random_state=RANDOM_STATE)

X_fit_red = pca.fit_transform(X_fit_scaled)
X_normal_red = pca.transform(X_normal_scaled)
X_fault1_red = pca.transform(X_fault1_scaled)
X_d2_red = pca.transform(X_d2_scaled)
X_d3_red = pca.transform(X_d3_scaled)

print("Nombre de composantes PCA :", n_components)
print("Variance expliquée totale :", round(pca.explained_variance_ratio_.sum(), 4))
# Out:
# Features après nettoyage : 262
# Nombre de composantes PCA : 3
# Variance expliquée totale : 0.6564
# c:\Users\louay\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1904: RuntimeWarning: overflow encountered in multiply
#   sqr = np.multiply(arr, arr, out=arr, where=where)

# %%
# ============================================================
# 6. FONCTIONS KDE
# ============================================================

def fit_kde_model(X_class, label, threshold_q, bandwidth_factor=1.0):
    """
    Entraîne une KDE sur une classe et calcule un seuil de densité.
    Si log_density >= threshold, le point est considéré comme compatible.
    """
    
    X_class = np.asarray(X_class)
    
    if len(X_class) < 3:
        raise ValueError(f"Pas assez de points pour entraîner KDE sur {label}")
    
    cv = min(5, len(X_class))
    
    grid = GridSearchCV(
        KernelDensity(kernel="gaussian"),
        {"bandwidth": BANDWIDTH_GRID},
        cv=cv
    )
    
    grid.fit(X_class)
    
    best_bw = grid.best_params_["bandwidth"]
    final_bw = best_bw * bandwidth_factor
    
    kde = KernelDensity(
        kernel="gaussian",
        bandwidth=final_bw
    )
    
    kde.fit(X_class)
    
    log_density_train = kde.score_samples(X_class)
    threshold = np.quantile(log_density_train, threshold_q)
    
    print(label)
    print("  nb points :", len(X_class))
    print("  bandwidth CV :", round(best_bw, 4))
    print("  bandwidth final :", round(final_bw, 4))
    print("  seuil KDE :", round(threshold, 4))
    
    return {
        "label": label,
        "kde": kde,
        "threshold": threshold,
        "threshold_q": threshold_q,
        "bandwidth": final_bw
    }


def classify_with_kde(X, ids, models, margins=None, accept_score_by_label=None):
    """
    Classe les points avec plusieurs KDE.
    
    Un point est accepté dans une classe si :
    - cette classe est celle qui a le meilleur score KDE
    - son score dépasse le seuil spécifique de cette classe
    
    Exemple :
    normal accepté si score >= 0.70
    fault_1 accepté si score >= 1.65
    """
    
    if margins is None:
        margins = {}
    
    if accept_score_by_label is None:
        accept_score_by_label = {}
    
    df_pred = pd.DataFrame()
    df_pred[ID_COL] = ids
    
    score_cols = []
    
    for label, model in models.items():
        log_density = model["kde"].score_samples(X)
        margin = margins.get(label, 0.0)
        
        score = log_density - model["threshold"] - margin
        
        df_pred[f"log_density_{label}"] = log_density
        df_pred[f"kde_score_{label}"] = score
        
        score_cols.append(f"kde_score_{label}")
    
    # Meilleure classe selon le score KDE
    df_pred["best_score_col"] = df_pred[score_cols].idxmax(axis=1)
    df_pred["best_label"] = df_pred["best_score_col"].str.replace("kde_score_", "", regex=False)
    df_pred["best_score"] = df_pred[score_cols].max(axis=1)
    
    # Seuil associé à la meilleure classe
    df_pred["accept_threshold"] = df_pred["best_label"].map(accept_score_by_label).fillna(0.0)
    
    # Par défaut : unknown
    df_pred["label_known"] = "unknown"
    
    # Acceptation seulement si le score dépasse le seuil de la classe prédite
    mask_accept = df_pred["best_score"] >= df_pred["accept_threshold"]
    
    df_pred.loc[mask_accept, "label_known"] = df_pred.loc[mask_accept, "best_label"]
    
    return df_pred

# %%
models_base = {}

models_base["normal"] = fit_kde_model(
    X_normal_red,
    label="normal",
    threshold_q=KDE_THRESHOLD_Q_NORMAL,
    bandwidth_factor=BW_FACTOR_NORMAL
)

models_base["fault_1"] = fit_kde_model(
    X_fault1_red,
    label="fault_1",
    threshold_q=KDE_THRESHOLD_Q_FAULT1,
    bandwidth_factor=BW_FACTOR_FAULT1
)

margins_base = {
    "normal": MARGIN_NORMAL,
    "fault_1": MARGIN_FAULT1
}
# Out:
# normal
#   nb points : 200
#   bandwidth CV : 1.1885
#   bandwidth final : 2.1393
#   seuil KDE : -9.544
# fault_1
#   nb points : 40
#   bandwidth CV : 2.5852
#   bandwidth final : 4.6534
#   seuil KDE : -10.1214

# %%
# ============================================================
# 8. TRAITEMENT DU DATASET2
# Objectif : reconnaître normal / fault_1, puis découvrir 2 défauts
# ============================================================

df_d2_pred = classify_with_kde(
    X_d2_red,
    ids=d2_agg[ID_COL].values,
    models=models_base,
    margins=margins_base,
    accept_score_by_label=ACCEPT_SCORE_BY_LABEL
)

print("Dataset2 - résultat KDE normal/fault_1 :")
print(df_d2_pred["label_known"].value_counts())

# Points non reconnus = défauts inconnus du dataset2
idx_d2_unknown = df_d2_pred[df_d2_pred["label_known"] == "unknown"].index
X_d2_unknown = X_d2_red[idx_d2_unknown]

print("Dataset2 - points inconnus à clusteriser :", len(X_d2_unknown))

if len(X_d2_unknown) <= N_D2_DEFECTS:
    raise ValueError("Pas assez de points unknown dans dataset2 pour apprendre les défauts.")
# Out:
# Dataset2 - résultat KDE normal/fault_1 :
# label_known
# normal     86
# unknown    56
# fault_1     8
# Name: count, dtype: int64
# Dataset2 - points inconnus à clusteriser : 56

# %%
# ============================================================
# 9. K-MEANS SUR LES UNKNOWN DU DATASET2
# ============================================================

kmeans_d2 = KMeans(
    n_clusters=N_D2_DEFECTS,
    random_state=RANDOM_STATE,
    n_init=50
)

d2_unknown_clusters = kmeans_d2.fit_predict(X_d2_unknown)

df_d2_pred["final_label"] = df_d2_pred["label_known"]

for cluster_id in range(N_D2_DEFECTS):
    local_idx = idx_d2_unknown[d2_unknown_clusters == cluster_id]
    df_d2_pred.loc[local_idx, "final_label"] = f"d2_defect_{cluster_id}"

print("Dataset2 - labels finaux :")
print(df_d2_pred["final_label"].value_counts())
# Out:
# Dataset2 - labels finaux :
# final_label
# normal         86
# d2_defect_0    32
# d2_defect_1    24
# fault_1         8
# Name: count, dtype: int64

# %%
print("Dataset2 - résultat KDE normal/fault_1 :")
print(df_d2_pred["label_known"].value_counts())

print("\nSeuils utilisés :")
print(df_d2_pred[["best_label", "best_score", "accept_threshold", "label_known"]].head(20))

print("\nNombre de points acceptés par seuil manuel :")
print("normal :", (df_d2_pred["kde_score_normal"] >= ACCEPT_SCORE_BY_LABEL["normal"]).sum())
print("fault_1 :", (df_d2_pred["kde_score_fault_1"] >= ACCEPT_SCORE_BY_LABEL["fault_1"]).sum())
# Out:
# Dataset2 - résultat KDE normal/fault_1 :
# label_known
# normal     86
# unknown    56
# fault_1     8
# Name: count, dtype: int64
#
# Seuils utilisés :
#    best_label  best_score  accept_threshold label_known
# 0      normal    2.368318               1.6      normal
# 1      normal    2.832444               1.6      normal
# 2      normal    2.939606               1.6      normal
# 3     fault_1   -5.518602               1.9     unknown
# 4      normal    2.296627               1.6      normal
# 5      normal    2.255624               1.6      normal
# 6      normal    1.878575               1.6      normal
# 7      normal    2.743710               1.6      normal
# 8      normal    2.116238               1.6      normal
# 9      normal    2.848782               1.6      normal
# 10     normal    1.317656               1.6     unknown
# 11     normal    1.788610               1.6      normal
# 12     normal    2.207771               1.6      normal
# 13     normal    2.695991               1.6      normal
# 14    fault_1   -4.827847               1.9     unknown
# 15     normal    2.005703               1.6      normal
# 16     normal    1.891984               1.6      normal
# 17    fault_1    1.014070               1.9     unknown
# 18     normal    2.721201               1.6      normal
# 19     normal    1.910871               1.6      normal
#
# Nombre de points acceptés par seuil manuel :
# normal : 86
# fault_1 : 8

# %%
print("\nPoints dataset2 les plus incertains :")

df_debug_d2 = df_d2_pred[
    [
        ID_COL,
        "kde_score_normal",
        "kde_score_fault_1",
        "best_label",
        "best_score",
        "label_known"
    ]
].copy()

# Les points proches de 0 sont les plus ambigus :
# score légèrement positif = accepté de justesse
# score légèrement négatif = rejeté de justesse
df_debug_d2["abs_best_score"] = df_debug_d2["best_score"].abs()

print(
    df_debug_d2
    .sort_values("abs_best_score")
    .head(3)
)
# Out:
# Points dataset2 les plus incertains :
#              i  kde_score_normal  kde_score_fault_1 best_label  best_score  \
# 147  ZI93DSRKV         -0.037700          -3.662223     normal   -0.037700
# 101  N30VVGTA0          0.287808          -3.918895     normal    0.287808
# 131  W11XA8KQ9          0.598273           0.697889    fault_1    0.697889
#
#     label_known  abs_best_score
# 147     unknown        0.037700
# 101     unknown        0.287808
# 131     unknown        0.697889

# %%
# =========================
# Table des identifiants les plus proches du défaut 1
# =========================

df_fault1_scores = df_d2_pred[
    [
        ID_COL,
        "kde_score_fault_1",
        "kde_score_normal",
        "best_label",
        "best_score",
        "label_known"
    ]
].copy()

# Tri du meilleur score fault_1 au moins bon
df_fault1_scores = df_fault1_scores.sort_values(
    by="kde_score_fault_1",
    ascending=False
)

# Afficher les 30 meilleurs candidats défaut 1
df_fault1_scores.head(5)
# Out:
#             i  kde_score_fault_1  kde_score_normal best_label  best_score  \
# 92  LGEGCYMBV           2.230337         -1.809067    fault_1    2.230337
# 86  JV9TP1C0Z           2.222174         -1.791321    fault_1    2.222174
# 73  GPJ515P0Y           2.206067         -3.423529    fault_1    2.206067
# 39  98LY7JJGA           2.145874         -0.674115    fault_1    2.145874
# 57  DAX1FW6U4           2.069020         -2.814321    fault_1    2.069020
#
#    label_known
# 92     fault_1
# 86     fault_1
# 73     fault_1
# 39     fault_1
# 57     fault_1

# %%
print("\nIdentifiants dataset2 classés unknown :")

print(
    df_d2_pred[df_d2_pred["label_known"] == "unknown"][
        [
            ID_COL,
            "kde_score_normal",
            "kde_score_fault_1",
            "best_label",
            "best_score",
            "label_known"
        ]
    ].head(5)
)
# Out:
# Identifiants dataset2 classés unknown :
#             i  kde_score_normal  kde_score_fault_1 best_label  best_score  \
# 3   1DACI9FCQ        -11.791825          -5.518602    fault_1   -5.518602
# 10  35X6YWYM3          1.317656          -5.920270     normal    1.317656
# 14  3JOJRSXPO         -7.023825          -4.827847    fault_1   -4.827847
# 17  4398XY0AP          0.121221           1.014070    fault_1    1.014070
# 20  4U2ZB99XF          0.719970           0.085975     normal    0.719970
#
#    label_known
# 3      unknown
# 10     unknown
# 14     unknown
# 17     unknown
# 20     unknown

# %%
# ============================================================
# 10. ENTRAÎNEMENT KDE SUR LES DÉFAUTS APPRIS DU DATASET2
# ============================================================

models_d2_defects = {}

for cluster_id in range(N_D2_DEFECTS):
    label = f"d2_defect_{cluster_id}"
    
    idx_label = df_d2_pred[df_d2_pred["final_label"] == label].index
    X_label = X_d2_red[idx_label]
    
    models_d2_defects[label] = fit_kde_model(
        X_label,
        label=label,
        threshold_q=KDE_THRESHOLD_Q_D2,
        bandwidth_factor=BW_FACTOR_D2
    )

models_all = {}
models_all.update(models_base)
models_all.update(models_d2_defects)

margins_all = {
    "normal": MARGIN_NORMAL,
    "fault_1": MARGIN_FAULT1,
    "d2_defect_0": MARGIN_D2_DEFECT,
    "d2_defect_1": MARGIN_D2_DEFECT
}
# Out:
# d2_defect_0
#   nb points : 32
#   bandwidth CV : 3.3497
#   bandwidth final : 4.0196
#   seuil KDE : -9.3981
# d2_defect_1
#   nb points : 24
#   bandwidth CV : 3.3497
#   bandwidth final : 4.0196
#   seuil KDE : -9.3481

# %%
# ============================================================
# 11. CLASSIFICATION DU DATASET3 AVEC KDE
# normal / fault_1 / d2_defect_0 / d2_defect_1 / unknown
# ============================================================

df_d3_pred = classify_with_kde(
    X_d3_red,
    ids=d3_agg[ID_COL].values,
    models=models_all,
    margins=margins_all,
    accept_score_by_label=ACCEPT_SCORE_BY_LABEL
)

print("Dataset3 - résultat KDE avant K-Means :")
print(df_d3_pred["label_known"].value_counts())

print("\nTop labels KDE :")
print(df_d3_pred[["best_label", "best_score"]].head())
# Out:
# Dataset3 - résultat KDE avant K-Means :
# label_known
# normal         76
# unknown        75
# fault_1         5
# d2_defect_1     4
# Name: count, dtype: int64
#
# Top labels KDE :
#   best_label  best_score
# 0    fault_1    0.734834
# 1    fault_1    1.694725
# 2     normal    2.851197
# 3    fault_1    2.081293
# 4     normal    1.410830

# %%
# ============================================================
# 12. K-MEANS SUR LES UNKNOWN DU DATASET3
# Objectif : découvrir 3 nouveaux défauts
# ============================================================

df_d3_pred["final_label"] = df_d3_pred["label_known"]

idx_d3_unknown = df_d3_pred[df_d3_pred["final_label"] == "unknown"].index
X_d3_unknown = X_d3_red[idx_d3_unknown]

print("Dataset3 - points unknown à clusteriser :", len(X_d3_unknown))

if len(X_d3_unknown) > N_D3_NEW_DEFECTS:
    
    kmeans_d3 = KMeans(
        n_clusters=N_D3_NEW_DEFECTS,
        random_state=RANDOM_STATE,
        n_init=50
    )
    
    d3_unknown_clusters = kmeans_d3.fit_predict(X_d3_unknown)
    
    for cluster_id in range(N_D3_NEW_DEFECTS):
        local_idx = idx_d3_unknown[d3_unknown_clusters == cluster_id]
        df_d3_pred.loc[local_idx, "final_label"] = f"new_defect_{cluster_id + 1}"
    
    if len(set(d3_unknown_clusters)) > 1:
        sil = silhouette_score(X_d3_unknown, d3_unknown_clusters)
        print("Silhouette K-Means dataset3 unknown :", round(sil, 4))

else:
    print("Pas assez de points unknown pour faire K-Means.")
# Out:
# Dataset3 - points unknown à clusteriser : 75
# Silhouette K-Means dataset3 unknown : 0.3428

# %%
# ============================================================
# 13. RÉSUMÉ FINAL DATASET3
# ============================================================

summary_d3 = df_d3_pred["final_label"].value_counts().reset_index()
summary_d3.columns = ["classe_predite", "nombre_identifiants"]

print(summary_d3)
print("\nTotal identifiants classifiés :", summary_d3["nombre_identifiants"].sum())
# Out:
#   classe_predite  nombre_identifiants
# 0         normal                   76
# 1   new_defect_3                   28
# 2   new_defect_2                   24
# 3   new_defect_1                   23
# 4        fault_1                    5
# 5    d2_defect_1                    4
#
# Total identifiants classifiés : 160

# %%
# ============================================================
# 14. TABLE COMPLÈTE DES RÉSULTATS DATASET3
# ============================================================

# Colonnes principales à afficher
base_cols = [
    ID_COL,
    "final_label",
    "label_known",
    "best_label",
    "best_score"
]

# Colonnes de seuil si elles existent
optional_cols = [
    "accept_threshold"
]

# Scores KDE disponibles
score_cols = [
    col for col in df_d3_pred.columns
    if col.startswith("kde_score_")
]

# Log densities si tu veux aussi les voir
log_density_cols = [
    col for col in df_d3_pred.columns
    if col.startswith("log_density_")
]

# On garde uniquement les colonnes qui existent vraiment
cols_to_show = [
    col for col in base_cols + optional_cols + score_cols
    if col in df_d3_pred.columns
]

# Création de la table finale
df_results_d3 = df_d3_pred[cols_to_show].copy()

# Tri pour lecture plus simple
df_results_d3 = df_results_d3.sort_values(
    by=["final_label", "best_score"],
    ascending=[True, False]
).reset_index(drop=True)

# Affichage de toute la table
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

#df_results_d3

# %% [markdown]
# ---
# Jour 3 : Dataset 4
# ---

# %%
nSet = 0
fileTS4 = os.path.join(os.getcwd(), "pdfTimeSeries4.pkl".format(nSet))
pdfTS4 = pd.read_pickle(fileTS4)

# %%
pdfTS4.head(1)
# Out:
#      u        y          i        e
# 0  0.0  0.12777  CNZQ0HOGP  0.12777

# %%
identifiant = "CNZQ0HOGP"

pdfTS4_filtre = pdfTS4[pdfTS4["i"] == identifiant]

pdfTS4_filtre["u"].plot(label="Entrée")
pdfTS4_filtre["y"].plot(label="Sortie")


plt.xlabel("Indice de la ligne")
plt.ylabel("Valeur")
plt.title(f"Signaux pour i = {identifiant}")
plt.grid()
plt.legend()
plt.show()

# %%
fileEF4 = os.path.join(os.getcwd(), "pdfFeatures4.pkl".format(nSet))
pdfEF4 = pd.read_pickle(fileEF4)

# %%
# ============================================================
# DATASET4 : PRÉPARATION
# ============================================================

df_d4 = pdfEF4.copy()

print("Dataset4 brut :", df_d4.shape)

# Vérification des features attendues
missing_cols = [col for col in feature_cols if col not in df_d4.columns]

if len(missing_cols) > 0:
    raise ValueError(f"Colonnes manquantes dans dataset4 : {missing_cols}")

# Agrégation : 1 ligne par identifiant
d4_agg = prepare_agg(df_d4, feature_cols, ID_COL)

print("Dataset4 agrégé :", d4_agg.shape)
print("Nombre d'identifiants dataset4 :", d4_agg[ID_COL].nunique())
# Out:
# Dataset4 brut : (78243, 275)
# Dataset4 agrégé : (315, 275)
# Nombre d'identifiants dataset4 : 315

# %%
# ============================================================
# DATASET4 : TRANSFORMATION AVEC LE MÊME PIPELINE
# ============================================================

X_d4 = d4_agg[feature_cols].copy()

# Remplacer infinis par NaN
X_d4 = X_d4.replace([np.inf, -np.inf], np.nan)

# Supprimer les colonnes supprimées pendant l'entraînement
if len(cols_all_nan) > 0:
    X_d4 = X_d4.drop(columns=cols_all_nan)

# Imputation avec l'imputer déjà entraîné
X_d4_imp = imputer.transform(X_d4)

X_d4_imp = pd.DataFrame(
    X_d4_imp,
    columns=X_d4.columns
)

# Suppression des colonnes constantes avec le selector déjà entraîné
X_d4_var = selector.transform(X_d4_imp)

X_d4_var = pd.DataFrame(
    X_d4_var,
    columns=selected_cols
)

# Clipping avec les bornes déjà calculées sur le train
X_d4_clip = X_d4_var.clip(lower=lower, upper=upper, axis=1)

# Scaling avec le scaler déjà entraîné
X_d4_scaled = scaler.transform(X_d4_clip)

X_d4_scaled = np.nan_to_num(
    X_d4_scaled,
    nan=0.0,
    posinf=0.0,
    neginf=0.0
)

# PCA avec la PCA déjà entraînée
X_d4_red = pca.transform(X_d4_scaled)

print("Shape dataset4 après PCA :", X_d4_red.shape)
# Out:
# Shape dataset4 après PCA : (315, 3)

# %%
# ============================================================
# DATASET4 : CLASSIFICATION KDE DES CLASSES CONNUES
# ============================================================

df_d4_pred = classify_with_kde(
    X_d4_red,
    ids=d4_agg[ID_COL].values,
    models=models_all,
    margins=margins_all,
    accept_score_by_label=ACCEPT_SCORE_BY_LABEL
)

print("Dataset4 - résultat KDE avant K-Means :")
print(df_d4_pred["label_known"].value_counts())

print("\nNombre total :", len(df_d4_pred))
# Out:
# Dataset4 - résultat KDE avant K-Means :
# label_known
# unknown        179
# normal          77
# d2_defect_1     35
# fault_1         24
# Name: count, dtype: int64
#
# Nombre total : 315

# %%
# ============================================================
# DATASET4 : TEST DE PLUSIEURS K SUR LES UNKNOWN
# ============================================================

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

idx_d4_unknown = df_d4_pred[df_d4_pred["label_known"] == "unknown"].index
X_d4_unknown = X_d4_red[idx_d4_unknown]

print("Nombre de points unknown dans dataset4 :", len(X_d4_unknown))

results_kmeans_d4 = []

# k > 3, donc on teste de 4 à 10
for k in range(4, 11):
    if len(X_d4_unknown) > k:
        
        kmeans = KMeans(
            n_clusters=k,
            random_state=RANDOM_STATE,
            n_init=50
        )
        
        clusters = kmeans.fit_predict(X_d4_unknown)
        
        silhouette = silhouette_score(X_d4_unknown, clusters)
        davies = davies_bouldin_score(X_d4_unknown, clusters)
        calinski = calinski_harabasz_score(X_d4_unknown, clusters)
        
        sizes = pd.Series(clusters).value_counts().sort_values(ascending=False).tolist()
        
        results_kmeans_d4.append({
            "k": k,
            "silhouette": round(silhouette, 4),
            "davies_bouldin": round(davies, 4),
            "calinski_harabasz": round(calinski, 2),
            "cluster_sizes": sizes
        })

df_results_kmeans_d4 = pd.DataFrame(results_kmeans_d4)

print(df_results_kmeans_d4)
# Out:
# Nombre de points unknown dans dataset4 : 179
#     k  silhouette  davies_bouldin  calinski_harabasz  \
# 0   4      0.3152          1.0819              78.03
# 1   5      0.3007          1.0403              79.10
# 2   6      0.3392          0.9099              81.39
# 3   7      0.3608          0.9004              88.28
# 4   8      0.3906          0.8325              93.53
# 5   9      0.3691          0.8679              92.42
# 6  10      0.3838          0.8375              92.14
#
#                            cluster_sizes
# 0                       [74, 46, 46, 13]
# 1                   [64, 42, 30, 28, 15]
# 2               [61, 38, 33, 24, 13, 10]
# 3           [53, 37, 35, 15, 13, 13, 13]
# 4        [53, 35, 31, 15, 13, 13, 10, 9]
# 5    [48, 30, 25, 25, 13, 10, 10, 10, 8]
# 6  [48, 28, 26, 24, 13, 10, 10, 8, 6, 6]

# %%
# ============================================================
# DATASET4 : CHOIX DU K FINAL
# ============================================================

K_D4_FINAL = 5  # à modifier après analyse du tableau précédent

print("K choisi pour dataset4 :", K_D4_FINAL)
# Out:
# K choisi pour dataset4 : 5

# %% [markdown]
# ---
# Résultats finaux dataset 4
# ---

# %%
# ============================================================
# DATASET4 : K-MEANS FINAL SUR LES UNKNOWN
# ============================================================

df_d4_pred["final_label"] = df_d4_pred["label_known"]

idx_d4_unknown = df_d4_pred[df_d4_pred["final_label"] == "unknown"].index
X_d4_unknown = X_d4_red[idx_d4_unknown]

if len(X_d4_unknown) > K_D4_FINAL:
    
    kmeans_d4_final = KMeans(
        n_clusters=K_D4_FINAL,
        random_state=RANDOM_STATE,
        n_init=50
    )
    
    d4_unknown_clusters = kmeans_d4_final.fit_predict(X_d4_unknown)
    
    for cluster_id in range(K_D4_FINAL):
        local_idx = idx_d4_unknown[d4_unknown_clusters == cluster_id]
        df_d4_pred.loc[local_idx, "final_label"] = f"d4_new_defect_{cluster_id + 1}"
else:
    print("Pas assez de points unknown pour appliquer K-Means.")

print("Répartition finale dataset4 :")
print(df_d4_pred["final_label"].value_counts())
# Out:
# Répartition finale dataset4 :
# final_label
# normal             77
# d4_new_defect_4    64
# d4_new_defect_5    42
# d2_defect_1        35
# d4_new_defect_2    30
# d4_new_defect_1    28
# fault_1            24
# d4_new_defect_3    15
# Name: count, dtype: int64

# %%
# ============================================================
# DATASET4 : RÉSUMÉ FINAL
# ============================================================

summary_d4 = df_d4_pred["final_label"].value_counts().reset_index()
summary_d4.columns = ["classe_predite", "nombre_identifiants"]

print(summary_d4)
print("\nTotal identifiants classifiés :", summary_d4["nombre_identifiants"].sum())
# Out:
#     classe_predite  nombre_identifiants
# 0           normal                   77
# 1  d4_new_defect_4                   64
# 2  d4_new_defect_5                   42
# 3      d2_defect_1                   35
# 4  d4_new_defect_2                   30
# 5  d4_new_defect_1                   28
# 6          fault_1                   24
# 7  d4_new_defect_3                   15
#
# Total identifiants classifiés : 315

# %%
# ============================================================
# DATASET4 : TABLE COMPLÈTE DES RÉSULTATS
# ============================================================

base_cols = [
    ID_COL,
    "final_label",
    "label_known",
    "best_label",
    "best_score"
]

optional_cols = [
    "accept_threshold"
]

score_cols = [
    col for col in df_d4_pred.columns
    if col.startswith("kde_score_")
]

log_density_cols = [
    col for col in df_d4_pred.columns
    if col.startswith("log_density_")
]

cols_to_show = [
    col for col in base_cols + optional_cols + score_cols
    if col in df_d4_pred.columns
]

df_results_d4 = df_d4_pred[cols_to_show].copy()

df_results_d4 = df_results_d4.sort_values(
    by=["final_label", "best_score"],
    ascending=[True, False]
).reset_index(drop=True)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

df_results_d4
# Out:
#              i      final_label  label_known   best_label  best_score  \
# 0    YCF3EHVXQ      d2_defect_1  d2_defect_1  d2_defect_1    1.225848
# 1    PS7Q740SI      d2_defect_1  d2_defect_1  d2_defect_1    1.182554
# 2    V3QPJCXCG      d2_defect_1  d2_defect_1  d2_defect_1    1.111837
# 3    KM1PAIX4Y      d2_defect_1  d2_defect_1  d2_defect_1    1.087852
# 4    XYBULRGK4      d2_defect_1  d2_defect_1  d2_defect_1    1.076643
# 5    10EXZ93B0      d2_defect_1  d2_defect_1  d2_defect_1    1.032415
# 6    LVMQ0X7KS      d2_defect_1  d2_defect_1  d2_defect_1    0.980482
# 7    T7NTL4E7P      d2_defect_1  d2_defect_1  d2_defect_1    0.970019
# 8    BINUQISSG      d2_defect_1  d2_defect_1  d2_defect_1    0.905306
# 9    YY30Y6FPK      d2_defect_1  d2_defect_1  d2_defect_1    0.890065
# 10   SJIK4R968      d2_defect_1  d2_defect_1  d2_defect_1    0.761905
# 11   2XV7E9Z1T      d2_defect_1  d2_defect_1  d2_defect_1    0.686802
# 12   717O188GR      d2_defect_1  d2_defect_1  d2_defect_1    0.568803
# 13   MJPXO12R0      d2_defect_1  d2_defect_1  d2_defect_1    0.562325
# 14   ASGNY3LNB      d2_defect_1  d2_defect_1  d2_defect_1    0.474048
# 15   2FNS5L6NO      d2_defect_1  d2_defect_1  d2_defect_1    0.448320
# 16   SV79VO8AX      d2_defect_1  d2_defect_1  d2_defect_1    0.443490
# 17   7UUESDVPC      d2_defect_1  d2_defect_1  d2_defect_1    0.419090
# 18   FWUIRZIUJ      d2_defect_1  d2_defect_1  d2_defect_1    0.406010
# 19   90GQAXQPA      d2_defect_1  d2_defect_1  d2_defect_1    0.385465
# 20   T4RM5U0P3      d2_defect_1  d2_defect_1  d2_defect_1    0.291367
# 21   WAMTGZAVI      d2_defect_1  d2_defect_1  d2_defect_1    0.288721
# 22   07QH7HPGI      d2_defect_1  d2_defect_1  d2_defect_1    0.266124
# 23   KLL3O8ZDR      d2_defect_1  d2_defect_1  d2_defect_1    0.204635
# 24   Z71QTNODE      d2_defect_1  d2_defect_1  d2_defect_1    0.111116
# 25   E0BN5HDDF      d2_defect_1  d2_defect_1  d2_defect_1    0.016581
# 26   WWISAQRCE      d2_defect_1  d2_defect_1  d2_defect_1   -0.036833
# 27   41KKGU17O      d2_defect_1  d2_defect_1  d2_defect_1   -0.108863
# 28   7YQ6J3Q2E      d2_defect_1  d2_defect_1  d2_defect_1   -0.155845
# 29   A66083ZBA      d2_defect_1  d2_defect_1  d2_defect_1   -0.185234
# 30   FXWF1E033      d2_defect_1  d2_defect_1  d2_defect_1   -0.217181
# 31   8PXPK1AMV      d2_defect_1  d2_defect_1  d2_defect_1   -0.224565
# 32   B4AURBB7R      d2_defect_1  d2_defect_1  d2_defect_1   -0.232770
# 33   HHLEXM12D      d2_defect_1  d2_defect_1  d2_defect_1   -0.277795
# 34   CT6HVC8O6      d2_defect_1  d2_defect_1  d2_defect_1   -0.300787
# 35   3ENOHNIGY  d4_new_defect_1      unknown      fault_1    1.883213
# 36   9C853UFYV  d4_new_defect_1      unknown      fault_1    1.835283
# 37   IA2F3X96D  d4_new_defect_1      unknown      fault_1    1.802812
# 38   UNJD4N5J4  d4_new_defect_1      unknown      fault_1    1.789111
# 39   YGLJOEYZA  d4_new_defect_1      unknown      fault_1    1.745825
# 40   7AIP20SB2  d4_new_defect_1      unknown      fault_1    1.520749
# 41   NZ9KRGKJH  d4_new_defect_1      unknown      fault_1    1.400584
# 42   RETCIKG2X  d4_new_defect_1      unknown      fault_1    1.266839
# 43   TBHG28YPT  d4_new_defect_1      unknown      fault_1    1.255038
# 44   DHSZAK84F  d4_new_defect_1      unknown      fault_1    1.204044
# 45   5GN5A6I1J  d4_new_defect_1      unknown      fault_1    1.150407
# 46   NNHBZXKXR  d4_new_defect_1      unknown      fault_1    1.079689
# 47   J7JDJORS2  d4_new_defect_1      unknown      fault_1    1.000212
# 48   TMDX0BOKC  d4_new_defect_1      unknown      fault_1    0.923653
# 49   9TUPQ4ZQB  d4_new_defect_1      unknown      fault_1    0.907387
# 50   53XW23G81  d4_new_defect_1      unknown      fault_1    0.822685
# 51   61MB4BLSD  d4_new_defect_1      unknown      fault_1    0.730416
# 52   U9Q9VQIR5  d4_new_defect_1      unknown      fault_1    0.669739
# 53   9ZG4ZLWUC  d4_new_defect_1      unknown      fault_1    0.669621
# 54   98XVR2R15  d4_new_defect_1      unknown      fault_1    0.587924
# 55   JUIL1K2H6  d4_new_defect_1      unknown      fault_1    0.489270
# 56   AB328FP4W  d4_new_defect_1      unknown      fault_1    0.438350
# 57   C5R4C8BY2  d4_new_defect_1      unknown      fault_1    0.407455
# 58   TSUBFHVAU  d4_new_defect_1      unknown      fault_1    0.282399
# 59   0ZC5A8YSY  d4_new_defect_1      unknown      fault_1    0.050566
# 60   8EO3GY3ON  d4_new_defect_1      unknown      fault_1   -0.088234
# 61   BLMXWKCCK  d4_new_defect_1      unknown  d2_defect_0   -0.576589
# 62   C7O5HTLU0  d4_new_defect_1      unknown  d2_defect_0   -0.818834
# 63   SZKNQ6YUQ  d4_new_defect_2      unknown      fault_1    1.766073
# 64   H0K9ZW7SC  d4_new_defect_2      unknown      fault_1    1.467251
# 65   W313A7IZF  d4_new_defect_2      unknown      fault_1    1.457705
# 66   EEEX2PQNN  d4_new_defect_2      unknown      fault_1    1.415382
# 67   B6ZN6KVM6  d4_new_defect_2      unknown      fault_1    1.340244
# 68   INSUG5EGI  d4_new_defect_2      unknown       normal    1.298984
# 69   SXGG37ZU6  d4_new_defect_2      unknown      fault_1    1.285341
# 70   AW7H8KGZN  d4_new_defect_2      unknown      fault_1    1.258572
# 71   W21LQCEGH  d4_new_defect_2      unknown      fault_1    1.240253
# 72   AB5YH66OQ  d4_new_defect_2      unknown      fault_1    1.126042
# 73   UKCWAGSW2  d4_new_defect_2      unknown      fault_1    1.039289
# 74   4R2TOAL20  d4_new_defect_2      unknown      fault_1    0.495300
# 75   IE8GGM2QW  d4_new_defect_2      unknown  d2_defect_0    0.339595
# 76   R4O84QDS3  d4_new_defect_2      unknown      fault_1    0.312546
# 77   AZGYI1UJP  d4_new_defect_2      unknown       normal    0.134406
# 78   UQVFVSQOD  d4_new_defect_2      unknown      fault_1    0.128447
# 79   IX4LMUVF9  d4_new_defect_2      unknown      fault_1    0.092738
# 80   JJXP8Q6I4  d4_new_defect_2      unknown      fault_1   -0.354715
# 81   9QOLCH47W  d4_new_defect_2      unknown      fault_1   -0.357656
# 82   9KN29G6HT  d4_new_defect_2      unknown      fault_1   -0.436371
# 83   M5GGK1E6T  d4_new_defect_2      unknown      fault_1   -0.585774
# 84   0ZJ3A1C1E  d4_new_defect_2      unknown  d2_defect_1   -1.154636
# 85   TLE5VDZAY  d4_new_defect_2      unknown      fault_1   -1.427333
# 86   T6TKMJSV6  d4_new_defect_2      unknown      fault_1   -1.464586
# 87   W72OMNVZY  d4_new_defect_2      unknown      fault_1   -1.560584
# 88   HFU14Z1DJ  d4_new_defect_2      unknown      fault_1   -1.653625
# 89   H0GWJ0IRA  d4_new_defect_2      unknown      fault_1   -1.760386
# 90   6ZCB0B64V  d4_new_defect_2      unknown      fault_1   -1.836461
# 91   1ZWI8NU0T  d4_new_defect_2      unknown  d2_defect_1   -1.894758
# 92   0ZB6Z15UJ  d4_new_defect_2      unknown  d2_defect_1   -2.045429
# 93   W13HQ3402  d4_new_defect_3      unknown      fault_1    1.786466
# 94   9MIT9X5LV  d4_new_defect_3      unknown      fault_1    1.607770
# 95   K083TZDX8  d4_new_defect_3      unknown      fault_1    1.519643
# 96   NZQGFZP8D  d4_new_defect_3      unknown      fault_1    1.501509
# 97   8MII7C7XY  d4_new_defect_3      unknown      fault_1    1.469863
# 98   U4EE8NED5  d4_new_defect_3      unknown      fault_1    1.293116
# 99   EDZ20WL56  d4_new_defect_3      unknown      fault_1    1.249452
# 100  27S60836S  d4_new_defect_3      unknown      fault_1    1.140325
# 101  JL1VZK8NM  d4_new_defect_3      unknown      fault_1    1.023824
# 102  ZV2YOXBBW  d4_new_defect_3      unknown      fault_1    0.995793
# 103  XPUY2MMNE  d4_new_defect_3      unknown      fault_1    0.919656
# 104  FFZK0JX3H  d4_new_defect_3      unknown      fault_1    0.888836
# 105  2RGNKV1S3  d4_new_defect_3      unknown      fault_1    0.574743
# 106  K8A92LEA3  d4_new_defect_3      unknown      fault_1    0.536474
# 107  GF6D3XQRV  d4_new_defect_3      unknown      fault_1    0.302566
# 108  ICY73ORUK  d4_new_defect_4      unknown      fault_1    1.839454
# 109  LVZ2KS3OQ  d4_new_defect_4      unknown      fault_1    1.830700
# 110  PU0G8V7XL  d4_new_defect_4      unknown      fault_1    1.797460
# 111  V3E9IQW97  d4_new_defect_4      unknown      fault_1    1.715996
# 112  JYVR0W33B  d4_new_defect_4      unknown      fault_1    1.715928
# 113  H5WXFBI4L  d4_new_defect_4      unknown      fault_1    1.693605
# 114  SZRBN29EC  d4_new_defect_4      unknown      fault_1    1.662819
# 115  SHNK9014D  d4_new_defect_4      unknown      fault_1    1.662085
# 116  8BCJGRAV4  d4_new_defect_4      unknown      fault_1    1.659683
# 117  KF446B6FB  d4_new_defect_4      unknown      fault_1    1.646832
# 118  8L3RBOBDT  d4_new_defect_4      unknown      fault_1    1.645765
# 119  DX9MGKCSQ  d4_new_defect_4      unknown      fault_1    1.645546
# 120  ET4YXN00E  d4_new_defect_4      unknown      fault_1    1.599769
# 121  8EG0EEJK2  d4_new_defect_4      unknown       normal    1.581099
# 122  SLJRMT3AZ  d4_new_defect_4      unknown      fault_1    1.573872
# 123  GZC47TAK1  d4_new_defect_4      unknown      fault_1    1.548660
# 124  45LWGA8ZG  d4_new_defect_4      unknown      fault_1    1.541889
# 125  UD3OI67PA  d4_new_defect_4      unknown       normal    1.516656
# 126  09XN3N7LX  d4_new_defect_4      unknown       normal    1.508872
# 127  Z5RYSR1OZ  d4_new_defect_4      unknown       normal    1.495813
# 128  U31PTREP8  d4_new_defect_4      unknown      fault_1    1.479610
# 129  XD0AF83JR  d4_new_defect_4      unknown      fault_1    1.458821
# 130  BLN5VN6LW  d4_new_defect_4      unknown      fault_1    1.439500
# 131  B33M321DG  d4_new_defect_4      unknown      fault_1    1.439166
# 132  GZZCVE8YA  d4_new_defect_4      unknown       normal    1.432024
# 133  FXTR4SUZE  d4_new_defect_4      unknown      fault_1    1.353954
# 134  URE3J87R5  d4_new_defect_4      unknown      fault_1    1.338461
# 135  MEMFNX1KT  d4_new_defect_4      unknown      fault_1    1.321847
# 136  KR58HRTDR  d4_new_defect_4      unknown      fault_1    1.311340
# 137  UB6MBA4AX  d4_new_defect_4      unknown      fault_1    1.277668
# 138  TULIQA493  d4_new_defect_4      unknown      fault_1    1.247301
# 139  7QGJJRXLN  d4_new_defect_4      unknown      fault_1    1.229606
# 140  A6BGH7S67  d4_new_defect_4      unknown      fault_1    1.214535
# 141  GPJJTI8KU  d4_new_defect_4      unknown      fault_1    1.203399
# 142  SBGE79KI6  d4_new_defect_4      unknown      fault_1    1.192876
# 143  YWCGQDVPO  d4_new_defect_4      unknown      fault_1    1.173026
# 144  QVR1JZFMK  d4_new_defect_4      unknown      fault_1    1.166970
# 145  MWKOQ920U  d4_new_defect_4      unknown      fault_1    1.165889
# 146  M71H2K2YZ  d4_new_defect_4      unknown       normal    1.161938
# 147  XO7I8SBJQ  d4_new_defect_4      unknown       normal    1.142831
# 148  ZMV7UDJYD  d4_new_defect_4      unknown      fault_1    1.131046
# 149  89Z2P3IAH  d4_new_defect_4      unknown       normal    1.115591
# 150  LPFP4APBW  d4_new_defect_4      unknown       normal    1.095989
# 151  BZFNZLVBJ  d4_new_defect_4      unknown      fault_1    1.079989
# 152  1LBYA1U72  d4_new_defect_4      unknown      fault_1    1.022908
# 153  LLMVHA7QL  d4_new_defect_4      unknown      fault_1    0.998739
# 154  UY19E4MDT  d4_new_defect_4      unknown      fault_1    0.996665
# 155  4VY0EU8JO  d4_new_defect_4      unknown       normal    0.995073
# 156  9HXE3NQXI  d4_new_defect_4      unknown      fault_1    0.992795
# 157  GHXSZMA7S  d4_new_defect_4      unknown       normal    0.984769
# 158  ZU9KG3OZ3  d4_new_defect_4      unknown  d2_defect_0    0.952377
# 159  NT4864QDH  d4_new_defect_4      unknown       normal    0.885089
# 160  RTMKSUQCH  d4_new_defect_4      unknown       normal    0.872189
# 161  LH1N93HJB  d4_new_defect_4      unknown      fault_1    0.860624
# 162  C11HDQ7F6  d4_new_defect_4      unknown  d2_defect_0    0.830522
# 163  SB30ZWA2H  d4_new_defect_4      unknown       normal    0.818784
# 164  RY3QHVKJ3  d4_new_defect_4      unknown       normal    0.766390
# 165  VXUXK2PNC  d4_new_defect_4      unknown      fault_1    0.737729
# 166  XO9K9P5Z5  d4_new_defect_4      unknown  d2_defect_0    0.635537
# 167  P4FPF0HIE  d4_new_defect_4      unknown      fault_1    0.625176
# 168  1MIK95K6E  d4_new_defect_4      unknown       normal    0.402594
# 169  25ADJEZGK  d4_new_defect_4      unknown      fault_1    0.359101
# 170  TV00B8AU6  d4_new_defect_4      unknown       normal    0.139750
# 171  0FZFH6BH7  d4_new_defect_4      unknown       normal   -0.196009
# 172  QUTAXES28  d4_new_defect_5      unknown       normal    1.403656
# 173  R36AN4IQA  d4_new_defect_5      unknown       normal    1.387216
# 174  J2UVM0GRJ  d4_new_defect_5      unknown       normal    1.219019
# 175  RXV8K4NGS  d4_new_defect_5      unknown       normal    1.097591
# 176  30T98M5X1  d4_new_defect_5      unknown       normal    1.037613
# 177  6I2TLD7HB  d4_new_defect_5      unknown       normal    0.849201
# 178  WOWJ7O03X  d4_new_defect_5      unknown       normal    0.765950
# 179  OG88PI6IT  d4_new_defect_5      unknown       normal    0.576386
# 180  O7GBQISDL  d4_new_defect_5      unknown       normal    0.330569
# 181  SZCD6ED6L  d4_new_defect_5      unknown       normal    0.269674
# 182  RMI2TZMQ5  d4_new_defect_5      unknown       normal   -0.095555
# 183  POE695RMU  d4_new_defect_5      unknown       normal   -0.227891
# 184  17MX3PPYU  d4_new_defect_5      unknown       normal   -0.283622
# 185  SRPL27P8T  d4_new_defect_5      unknown      fault_1   -0.503436
# 186  TUG8PBGHV  d4_new_defect_5      unknown  d2_defect_0   -0.563012
# 187  9OO2VTL3C  d4_new_defect_5      unknown      fault_1   -0.576437
# 188  B8FJQ77U9  d4_new_defect_5      unknown  d2_defect_1   -0.668875
# 189  MCOAOZQEQ  d4_new_defect_5      unknown  d2_defect_0   -0.688482
# 190  D4N8X8MZI  d4_new_defect_5      unknown  d2_defect_1   -0.699329
# 191  SZJZS199Z  d4_new_defect_5      unknown  d2_defect_1   -0.730512
# 192  982MJ5XT0  d4_new_defect_5      unknown  d2_defect_1   -0.819238
# 193  AB12XC90U  d4_new_defect_5      unknown      fault_1   -0.904008
# 194  E0XJ3F2F2  d4_new_defect_5      unknown  d2_defect_0   -0.933122
# 195  1TRIVLK9L  d4_new_defect_5      unknown  d2_defect_1   -0.934333
# 196  CARLAVKKN  d4_new_defect_5      unknown  d2_defect_1   -0.987583
# 197  ZFVYR4UTO  d4_new_defect_5      unknown  d2_defect_0   -1.068652
# 198  NT81MEQP3  d4_new_defect_5      unknown  d2_defect_1   -1.096312
# 199  7ZT9RNCQZ  d4_new_defect_5      unknown  d2_defect_1   -1.130511
# 200  6ZR6K38DJ  d4_new_defect_5      unknown       normal   -1.138450
# 201  UGSYAWO6W  d4_new_defect_5      unknown  d2_defect_0   -1.139449
# 202  1ATUQSLWI  d4_new_defect_5      unknown  d2_defect_0   -1.314643
# 203  OMKRLMK0X  d4_new_defect_5      unknown  d2_defect_1   -1.352362
# 204  0MDER14PM  d4_new_defect_5      unknown      fault_1   -1.405411
# 205  07V3DLJ40  d4_new_defect_5      unknown  d2_defect_0   -1.406263
# 206  VFJGV9811  d4_new_defect_5      unknown  d2_defect_1   -1.410999
# 207  5JY84AR5U  d4_new_defect_5      unknown  d2_defect_0   -1.422619
# 208  SWKLPK3KC  d4_new_defect_5      unknown  d2_defect_0   -1.424236
# 209  RSQSPHF6S  d4_new_defect_5      unknown  d2_defect_1   -1.467740
# 210  N2BGKK6KO  d4_new_defect_5      unknown  d2_defect_1   -1.495149
# 211  D1J3Q2WS8  d4_new_defect_5      unknown      fault_1   -1.549391
# 212  SC8D8QPQQ  d4_new_defect_5      unknown  d2_defect_0   -1.580032
# 213  Z2PB44SZ1  d4_new_defect_5      unknown  d2_defect_1   -1.653244
# 214  NJIXEK4SM          fault_1      fault_1      fault_1    2.295765
# 215  MMLIYWVYD          fault_1      fault_1      fault_1    2.265673
# 216  13ZZ3MRKG          fault_1      fault_1      fault_1    2.265617
# 217  WD0OY0L79          fault_1      fault_1      fault_1    2.234642
# 218  19I6XXD8A          fault_1      fault_1      fault_1    2.226221
# 219  DGXQLSFWD          fault_1      fault_1      fault_1    2.216404
# 220  XF2OUSJEF          fault_1      fault_1      fault_1    2.214464
# 221  ZIDEC2HCE          fault_1      fault_1      fault_1    2.207847
# 222  FJ5WB2CDL          fault_1      fault_1      fault_1    2.179171
# 223  1Q20UWQCS          fault_1      fault_1      fault_1    2.178786
# 224  TKED9VHII          fault_1      fault_1      fault_1    2.169372
# 225  KJRL2MUWE          fault_1      fault_1      fault_1    2.149552
# 226  HCOKARUSP          fault_1      fault_1      fault_1    2.118475
# 227  Z8DV97OBM          fault_1      fault_1      fault_1    2.117356
# 228  HNPH0D86P          fault_1      fault_1      fault_1    2.082784
# 229  B2JRZY0ZA          fault_1      fault_1      fault_1    2.067371
# 230  8XIZYR3IW          fault_1      fault_1      fault_1    2.066952
# 231  OQWL2Y07K          fault_1      fault_1      fault_1    2.061022
# 232  0CDF1G71M          fault_1      fault_1      fault_1    2.041374
# 233  PTY557JUG          fault_1      fault_1      fault_1    2.024227
# 234  TTBPOKRS4          fault_1      fault_1      fault_1    1.996551
# 235  NJTO37HME          fault_1      fault_1      fault_1    1.987535
# 236  FN5P172FF          fault_1      fault_1      fault_1    1.978062
# 237  K1KZJA4MI          fault_1      fault_1      fault_1    1.964603
# 238  N2Z41MUEY           normal       normal       normal    3.182226
# 239  Q7P9TYYCU           normal       normal       normal    3.099710
# 240  0B9FRWJVR           normal       normal       normal    3.060376
# 241  CNZQ0HOGP           normal       normal       normal    3.050844
# 242  N6JOL3DWU           normal       normal       normal    3.002792
# 243  N3I95AF9M           normal       normal       normal    2.983809
# 244  QIMBHIAH4           normal       normal       normal    2.979762
# 245  N57FPLC7R           normal       normal       normal    2.937732
# 246  67NSO22YI           normal       normal       normal    2.930528
# 247  7QBB514C2           normal       normal       normal    2.922312
# 248  B5BELEZOY           normal       normal       normal    2.895489
# 249  CG4F2AWF2           normal       normal       normal    2.885107
# 250  MRHX45DVG           normal       normal       normal    2.874426
# 251  BGCXDNWTM           normal       normal       normal    2.868840
# 252  9KWZTSIG9           normal       normal       normal    2.838582
# 253  P86EO1SL6           normal       normal       normal    2.833556
# 254  FYIVP8OOP           normal       normal       normal    2.816638
# 255  67B11U0JO           normal       normal       normal    2.814427
# 256  J33MXHSZ5           normal       normal       normal    2.800677
# 257  FSE9R0NTA           normal       normal       normal    2.778266
# 258  I84YSPTWC           normal       normal       normal    2.756956
# 259  KVADV1YWX           normal       normal       normal    2.731345
# 260  KVMH4OF2R           normal       normal       normal    2.719728
# 261  1SVL9MJPB           normal       normal       normal    2.709835
# 262  N05NT25GJ           normal       normal       normal    2.694837
# 263  QZISXJY4T           normal       normal       normal    2.692819
# 264  CCGSLN7XQ           normal       normal       normal    2.679509
# 265  MJTHGD6G0           normal       normal       normal    2.679174
# 266  YE9MSLPLM           normal       normal       normal    2.631738
# 267  UJ0JQLZKR           normal       normal       normal    2.631231
# 268  38CD29RUT           normal       normal       normal    2.614595
# 269  48A6CDFC1           normal       normal       normal    2.607680
# 270  RJAD36SYY           normal       normal       normal    2.591030
# 271  PF1TK3O88           normal       normal       normal    2.566391
# 272  51RTX2WG5           normal       normal       normal    2.516447
# 273  A5UBYEQL0           normal       normal       normal    2.513994
# 274  WSLZLT1CO           normal       normal       normal    2.459706
# 275  B8YJPZJ5F           normal       normal       normal    2.389523
# 276  APWX88LG5           normal       normal       normal    2.372578
# 277  M9KQ5PFHF           normal       normal       normal    2.368979
# 278  A6QSXVRTW           normal       normal       normal    2.364388
# 279  H85ECGXGC           normal       normal       normal    2.357690
# 280  HZJCIJ6XB           normal       normal       normal    2.338084
# 281  65OX763QS           normal       normal       normal    2.299885
# 282  GDNHW6B73           normal       normal       normal    2.289649
# 283  5ATGSOKDF           normal       normal       normal    2.289331
# 284  ODYQQS05K           normal       normal       normal    2.260032
# 285  65TZ5MVEH           normal       normal       normal    2.237316
# 286  T31OU6D0R           normal       normal       normal    2.235298
# 287  NCLM2A42Y           normal       normal       normal    2.213544
# 288  VVLKO00V9           normal       normal       normal    2.169936
# 289  YCA7VRXV7           normal       normal       normal    2.114450
# 290  SI2SIAUQ9           normal       normal       normal    2.109329
# 291  72ZGECAXG           normal       normal       normal    2.092706
# 292  YRVWQ0UJ1           normal       normal       normal    2.086495
# 293  8WCQFV3Z0           normal       normal       normal    2.084873
# 294  N1ONVRHW8           normal       normal       normal    2.082186
# 295  173BJRSXY           normal       normal       normal    2.050443
# 296  G5WG0BB6F           normal       normal       normal    2.044223
# 297  3JUEYN8S1           normal       normal       normal    2.009983
# 298  OA698ZRPB           normal       normal       normal    2.006311
# 299  6275GYVRG           normal       normal       normal    1.984979
# 300  2BOA4V0SQ           normal       normal       normal    1.959993
# 301  J49IIGXSD           normal       normal       normal    1.930858
# 302  HT1AYE1JJ           normal       normal       normal    1.922942
# 303  RCH26B7CB           normal       normal       normal    1.903805
# 304  P2OLMPX0J           normal       normal       normal    1.876228
# 305  7UHNED5RO           normal       normal       normal    1.871404
# 306  3VSUKT7ME           normal       normal       normal    1.849217
# 307  YWBQGNF2M           normal       normal       normal    1.835209
# 308  V9RF3WYZ1           normal       normal       normal    1.812161
# 309  XKEAGD2SO           normal       normal       normal    1.802196
# 310  WYQ1C5HUX           normal       normal       normal    1.800813
# 311  V4RGY71R4           normal       normal       normal    1.759632
# 312  0SKAL1AUW           normal       normal       normal    1.726065
# 313  V0B4P7SI5           normal       normal       normal    1.646624
# 314  3GW7W9V5H           normal       normal       normal    1.643514
#
#      accept_threshold  kde_score_normal  kde_score_fault_1  \
# 0                -0.5        -47.623581          -7.391860
# 1                -0.5        -54.911238          -8.628468
# 2                -0.5        -60.228172         -11.011854
# 3                -0.5        -66.772556         -10.970171
# 4                -0.5        -46.586798          -7.463949
# 5                -0.5        -51.472752          -8.958527
# 6                -0.5        -46.687080          -5.743238
# 7                -0.5        -59.442287         -10.677542
# 8                -0.5        -46.470273          -8.152497
# 9                -0.5        -66.230827          -9.392424
# 10               -0.5        -52.872282         -10.099558
# 11               -0.5        -71.631838          -9.979324
# 12               -0.5        -68.851004          -8.859865
# 13               -0.5        -47.567124          -8.971050
# 14               -0.5        -35.698890          -6.204869
# 15               -0.5        -36.231908          -5.455560
# 16               -0.5        -62.199129          -8.444623
# 17               -0.5        -45.438364          -8.710187
# 18               -0.5        -36.684229          -7.225223
# 19               -0.5        -32.641736          -6.182110
# 20               -0.5        -58.075610          -9.312163
# 21               -0.5        -42.528891          -5.052928
# 22               -0.5        -66.399129         -10.032384
# 23               -0.5        -31.587307          -4.938074
# 24               -0.5        -31.428600          -6.747170
# 25               -0.5        -70.290604          -8.743448
# 26               -0.5        -66.143793          -9.096114
# 27               -0.5        -24.032239          -5.016845
# 28               -0.5        -35.944811          -8.395264
# 29               -0.5        -22.795457          -6.443555
# 30               -0.5        -65.917373          -7.134637
# 31               -0.5        -28.356653          -6.527351
# 32               -0.5        -23.532422          -6.830281
# 33               -0.5        -21.797128          -5.091830
# 34               -0.5        -30.756600          -7.383193
# 35                1.9         -8.648779           1.883213
# 36                1.9        -13.566629           1.835283
# 37                1.9         -0.652006           1.802812
# 38                1.9         -5.068858           1.789111
# 39                1.9        -12.290902           1.745825
# 40                1.9         -1.769425           1.520749
# 41                1.9         -8.552032           1.400584
# 42                1.9         -8.568980           1.266839
# 43                1.9        -22.767715           1.255038
# 44                1.9         -2.082265           1.204044
# 45                1.9         -2.417995           1.150407
# 46                1.9         -0.888016           1.079689
# 47                1.9        -26.278949           1.000212
# 48                1.9         -1.325190           0.923653
# 49                1.9         -8.186117           0.907387
# 50                1.9         -0.253780           0.822685
# 51                1.9         -0.760081           0.730416
# 52                1.9          0.159474           0.669739
# 53                1.9        -16.845669           0.669621
# 54                1.9         -1.036313           0.587924
# 55                1.9        -18.409845           0.489270
# 56                1.9         -0.619472           0.438350
# 57                1.9         -0.668146           0.407455
# 58                1.9        -29.400751           0.282399
# 59                1.9         -1.827976           0.050566
# 60                1.9         -4.633651          -0.088234
# 61                1.0         -1.205817          -0.676712
# 62                1.0         -3.374668          -2.658773
# 63                1.9         -2.035121           1.766073
# 64                1.9          0.883237           1.467251
# 65                1.9         -0.302110           1.457705
# 66                1.9          0.602508           1.415382
# 67                1.9         -3.649411           1.340244
# 68                1.6          1.298984           0.893522
# 69                1.9          0.619511           1.285341
# 70                1.9         -0.960841           1.258572
# 71                1.9         -5.627581           1.240253
# 72                1.9         -0.666014           1.126042
# 73                1.9         -1.193096           1.039289
# 74                1.9        -14.487638           0.495300
# 75                1.0         -0.312479          -0.082887
# 76                1.9         -2.606798           0.312546
# 77                1.6          0.134406          -0.741138
# 78                1.9         -1.510621           0.128447
# 79                1.9         -2.550778           0.092738
# 80                1.9         -8.047155          -0.354715
# 81                1.9         -2.189065          -0.357656
# 82                1.9        -16.359235          -0.436371
# 83                1.9        -14.701100          -0.585774
# 84               -0.5        -46.995123          -8.123948
# 85                1.9        -10.018669          -1.427333
# 86                1.9         -5.641758          -1.464586
# 87                1.9         -8.304042          -1.560584
# 88                1.9         -6.408461          -1.653625
# 89                1.9        -16.281891          -1.760386
# 90                1.9        -20.818617          -1.836461
# 91               -0.5        -37.642121          -6.097581
# 92               -0.5         -8.374531          -2.210730
# 93                1.9         -9.150783           1.786466
# 94                1.9        -21.595598           1.607770
# 95                1.9        -14.718718           1.519643
# 96                1.9        -18.810492           1.501509
# 97                1.9        -17.974767           1.469863
# 98                1.9        -30.743846           1.293116
# 99                1.9        -11.639308           1.249452
# 100               1.9        -10.114740           1.140325
# 101               1.9        -38.821704           1.023824
# 102               1.9        -37.004274           0.995793
# 103               1.9        -40.257279           0.919656
# 104               1.9         -6.045948           0.888836
# 105               1.9        -47.079688           0.574743
# 106               1.9        -15.322655           0.536474
# 107               1.9        -49.200069           0.302566
# 108               1.9         -1.765847           1.839454
# 109               1.9          0.974200           1.830700
# 110               1.9         -2.054661           1.797460
# 111               1.9          0.043697           1.715996
# 112               1.9          0.869858           1.715928
# 113               1.9         -1.444615           1.693605
# 114               1.9          0.754633           1.662819
# 115               1.9          0.459205           1.662085
# 116               1.9          0.536421           1.659683
# 117               1.9         -0.586164           1.646832
# 118               1.9          1.434030           1.645765
# 119               1.9          0.679823           1.645546
# 120               1.9          1.235312           1.599769
# 121               1.6          1.581099           1.327448
# 122               1.9          0.086804           1.573872
# 123               1.9          1.419164           1.548660
# 124               1.9          0.826270           1.541889
# 125               1.6          1.516656          -2.655445
# 126               1.6          1.508872          -0.719852
# 127               1.6          1.495813           1.174892
# 128               1.9          0.769906           1.479610
# 129               1.9         -1.058745           1.458821
# 130               1.9         -0.354472           1.439500
# 131               1.9         -2.384994           1.439166
# 132               1.6          1.432024           0.107325
# 133               1.9         -0.117818           1.353954
# 134               1.9          0.514699           1.338461
# 135               1.9          0.824359           1.321847
# 136               1.9          0.153143           1.311340
# 137               1.9          1.185241           1.277668
# 138               1.9          0.629011           1.247301
# 139               1.9          0.521254           1.229606
# 140               1.9          0.628004           1.214535
# 141               1.9          1.171163           1.203399
# 142               1.9         -0.744662           1.192876
# 143               1.9          1.059226           1.173026
# 144               1.9         -2.088146           1.166970
# 145               1.9          0.615058           1.165889
# 146               1.6          1.161938           0.385190
# 147               1.6          1.142831           1.104294
# 148               1.9         -0.112047           1.131046
# 149               1.6          1.115591          -0.381305
# 150               1.6          1.095989          -2.206231
# 151               1.9         -1.329872           1.079989
# 152               1.9          0.398622           1.022908
# 153               1.9          0.798073           0.998739
# 154               1.9          0.337329           0.996665
# 155               1.6          0.995073          -5.057229
# 156               1.9          0.201053           0.992795
# 157               1.6          0.984769          -2.931656
# 158               1.0          0.494869           0.341580
# 159               1.6          0.885089           0.785630
# 160               1.6          0.872189           0.580842
# 161               1.9          0.415181           0.860624
# 162               1.0         -0.455715           0.750775
# 163               1.6          0.818784          -0.071899
# 164               1.6          0.766390          -1.849836
# 165               1.9         -0.320136           0.737729
# 166               1.0         -0.766472          -0.617218
# 167               1.9          0.533100           0.625176
# 168               1.6          0.402594          -5.975827
# 169               1.9         -1.344629           0.359101
# 170               1.6          0.139750          -0.315801
# 171               1.6         -0.196009          -5.982181
# 172               1.6          1.403656          -5.545429
# 173               1.6          1.387216          -0.406295
# 174               1.6          1.219019          -0.981611
# 175               1.6          1.097591          -5.654339
# 176               1.6          1.037613          -4.943028
# 177               1.6          0.849201           0.004217
# 178               1.6          0.765950          -1.573836
# 179               1.6          0.576386          -3.802183
# 180               1.6          0.330569          -6.850891
# 181               1.6          0.269674          -2.274226
# 182               1.6         -0.095555          -2.598781
# 183               1.6         -0.227891          -1.826754
# 184               1.6         -0.283622          -1.850714
# 185               1.9         -0.940991          -0.503436
# 186               1.0         -0.563136          -0.642238
# 187               1.9         -4.726426          -0.576437
# 188              -0.5        -21.086602          -7.900576
# 189               1.0         -0.739622          -0.767315
# 190              -0.5        -11.387758          -3.206813
# 191              -0.5        -24.021954          -4.045160
# 192              -0.5         -5.778282          -8.197077
# 193               1.9         -8.870776          -0.904008
# 194               1.0         -1.257974          -1.093572
# 195              -0.5         -6.544457          -2.594669
# 196              -0.5         -2.963970          -3.385694
# 197               1.0         -1.649355          -1.232573
# 198              -0.5         -2.439569          -3.690162
# 199              -0.5        -14.427954          -5.738974
# 200               1.6         -1.138450          -2.623793
# 201               1.0         -1.534465          -1.363225
# 202               1.0         -1.693436          -1.628779
# 203              -0.5        -10.276302          -1.768383
# 204               1.9         -3.925551          -1.405411
# 205               1.0         -2.696202          -1.564431
# 206              -0.5         -3.309881          -1.680976
# 207               1.0         -2.997958          -1.456711
# 208               1.0         -1.945137          -2.186307
# 209              -0.5         -3.165128          -1.611306
# 210              -0.5         -7.070542          -1.593544
# 211               1.9        -15.003864          -1.549391
# 212               1.0         -5.549027          -2.337906
# 213              -0.5         -7.872645          -3.191385
# 214               1.9         -1.641219           2.295765
# 215               1.9         -4.262469           2.265673
# 216               1.9         -3.123610           2.265617
# 217               1.9         -1.334729           2.234642
# 218               1.9         -6.158291           2.226221
# 219               1.9         -2.059710           2.216404
# 220               1.9         -0.252717           2.214464
# 221               1.9         -2.143377           2.207847
# 222               1.9         -6.872951           2.179171
# 223               1.9         -0.961424           2.178786
# 224               1.9         -2.133886           2.169372
# 225               1.9          0.122056           2.149552
# 226               1.9         -0.482156           2.118475
# 227               1.9         -4.689398           2.117356
# 228               1.9         -5.869560           2.082784
# 229               1.9        -10.084198           2.067371
# 230               1.9         -3.289984           2.066952
# 231               1.9         -0.094027           2.061022
# 232               1.9          0.105611           2.041374
# 233               1.9         -8.302250           2.024227
# 234               1.9         -0.534038           1.996551
# 235               1.9         -7.102978           1.987535
# 236               1.9         -9.771331           1.978062
# 237               1.9         -0.994689           1.964603
# 238               1.6          3.182226          -1.810767
# 239               1.6          3.099710          -0.815117
# 240               1.6          3.060376          -3.057154
# 241               1.6          3.050844          -2.683018
# 242               1.6          3.002792          -0.660251
# 243               1.6          2.983809          -0.752600
# 244               1.6          2.979762          -1.019150
# 245               1.6          2.937732          -2.352979
# 246               1.6          2.930528          -1.605947
# 247               1.6          2.922312          -3.064417
# 248               1.6          2.895489          -1.354813
# 249               1.6          2.885107          -1.245370
# 250               1.6          2.874426          -0.700862
# 251               1.6          2.868840          -2.375579
# 252               1.6          2.838582          -2.607954
# 253               1.6          2.833556          -0.901070
# 254               1.6          2.816638          -1.651708
# 255               1.6          2.814427          -0.966066
# 256               1.6          2.800677          -0.229023
# 257               1.6          2.778266          -0.741627
# 258               1.6          2.756956          -0.555902
# 259               1.6          2.731345          -1.046932
# 260               1.6          2.719728          -0.014035
# 261               1.6          2.709835          -1.707375
# 262               1.6          2.694837          -2.151024
# 263               1.6          2.692819          -0.024525
# 264               1.6          2.679509          -3.079265
# 265               1.6          2.679174          -1.248090
# 266               1.6          2.631738          -1.551269
# 267               1.6          2.631231          -3.555286
# 268               1.6          2.614595          -2.438897
# 269               1.6          2.607680          -1.983604
# 270               1.6          2.591030          -3.323939
# 271               1.6          2.566391           0.039670
# 272               1.6          2.516447          -4.375224
# 273               1.6          2.513994          -0.120385
# 274               1.6          2.459706           0.631203
# 275               1.6          2.389523           0.000085
# 276               1.6          2.372578          -1.714193
# 277               1.6          2.368979          -2.952703
# 278               1.6          2.364388          -0.628838
# 279               1.6          2.357690          -0.831259
# 280               1.6          2.338084           0.307465
# 281               1.6          2.299885           0.394527
# 282               1.6          2.289649           0.314626
# 283               1.6          2.289331          -1.085290
# 284               1.6          2.260032           0.427831
# 285               1.6          2.237316           0.944658
# 286               1.6          2.235298          -3.029941
# 287               1.6          2.213544          -2.683866
# 288               1.6          2.169936          -1.084294
# 289               1.6          2.114450           0.348254
# 290               1.6          2.109329           0.703038
# 291               1.6          2.092706          -0.900158
# 292               1.6          2.086495          -3.521593
# 293               1.6          2.084873          -1.831019
# 294               1.6          2.082186           0.212684
# 295               1.6          2.050443           0.154626
# 296               1.6          2.044223           0.355135
# 297               1.6          2.009983           0.876864
# 298               1.6          2.006311           1.063822
# 299               1.6          1.984979           0.830294
# 300               1.6          1.959993          -2.179302
# 301               1.6          1.930858          -3.482283
# 302               1.6          1.922942           0.639986
# 303               1.6          1.903805           0.471082
# 304               1.6          1.876228           0.036130
# 305               1.6          1.871404          -0.170210
# 306               1.6          1.849217          -0.208523
# 307               1.6          1.835209           0.866560
# 308               1.6          1.812161           0.228043
# 309               1.6          1.802196          -2.326051
# 310               1.6          1.800813          -0.463824
# 311               1.6          1.759632          -1.442550
# 312               1.6          1.726065           0.290610
# 313               1.6          1.646624          -1.421638
# 314               1.6          1.643514          -4.916696
#
#      kde_score_d2_defect_0  kde_score_d2_defect_1
# 0               -11.389134               1.225848
# 1               -14.827302               1.182554
# 2               -15.301063               1.111837
# 3               -14.071646               1.087852
# 4               -10.338771               1.076643
# 5               -12.370422               1.032415
# 6               -12.087005               0.980482
# 7               -16.079214               0.970019
# 8               -10.355508               0.905306
# 9               -16.495160               0.890065
# 10              -12.615870               0.761905
# 11              -17.940220               0.686802
# 12              -16.974917               0.568803
# 13               -9.240317               0.562325
# 14               -8.909050               0.474048
# 15               -9.175482               0.448320
# 16              -15.820113               0.443490
# 17              -11.320337               0.419090
# 18               -8.553755               0.406010
# 19               -7.444426               0.385465
# 20              -14.281369               0.291367
# 21              -11.561439               0.288721
# 22              -16.967931               0.266124
# 23               -8.046154               0.204635
# 24               -5.464678               0.111116
# 25              -15.962604               0.016581
# 26              -16.306796              -0.036833
# 27               -4.536250              -0.108863
# 28               -5.359458              -0.155845
# 29               -6.973119              -0.185234
# 30              -13.847457              -0.217181
# 31               -4.109636              -0.224565
# 32               -7.624668              -0.232770
# 33               -6.035132              -0.277795
# 34               -4.263293              -0.300787
# 35               -1.697167              -9.984612
# 36               -1.981181             -12.379788
# 37                0.282581              -9.111143
# 38               -0.680862             -10.445465
# 39               -2.242389             -12.317836
# 40                0.261764             -10.848617
# 41               -1.364182             -10.341092
# 42               -1.369381              -8.855034
# 43               -1.937759             -12.278278
# 44                0.252771              -9.975771
# 45                0.149505              -8.798735
# 46                0.446777              -9.322123
# 47               -2.039029             -11.941677
# 48                0.342197              -9.344833
# 49               -1.309893              -6.688896
# 50                0.454856              -7.468068
# 51                0.380464              -9.248639
# 52                0.483481              -7.967242
# 53               -3.425114             -11.186292
# 54                0.187258              -7.949182
# 55               -3.703284              -7.934025
# 56                0.205335              -7.916308
# 57                0.237163              -8.685827
# 58               -4.952638             -12.234510
# 59               -0.452613              -8.482271
# 60               -1.399367              -7.395220
# 61               -0.576589              -8.559163
# 62               -0.818834              -6.861878
# 63               -1.075935              -5.648693
# 64                0.072189              -6.584667
# 65                0.035093              -6.754758
# 66               -0.048718              -6.225620
# 67               -0.240284              -8.309631
# 68                0.618140              -7.967359
# 69               -0.161430              -5.821554
# 70                0.377531              -8.665421
# 71               -0.564479              -9.018198
# 72               -0.749838              -4.453312
# 73                0.275908              -8.514275
# 74               -4.058593              -3.068727
# 75                0.339595              -9.518076
# 76               -1.121572              -3.248182
# 77               -0.242374              -5.974032
# 78               -1.132930              -3.789018
# 79               -1.391364              -3.563742
# 80               -2.140126              -2.047759
# 81               -1.331475              -3.566277
# 82               -4.808006              -3.296786
# 83               -3.705757              -1.563758
# 84              -12.771920              -1.154636
# 85               -3.770221              -1.933794
# 86               -1.889507              -2.334553
# 87               -3.098072              -1.648454
# 88               -2.460976              -2.640811
# 89               -5.197715              -2.749062
# 90               -6.559827              -2.191536
# 91              -11.232859              -1.894758
# 92               -2.712903              -2.045429
# 93               -1.373859             -11.132807
# 94               -1.441273             -17.541745
# 95               -1.943333             -16.080769
# 96               -2.037563             -16.176835
# 97               -2.109946             -18.893093
# 98               -1.151920             -14.790374
# 99               -1.147409             -13.101214
# 100              -0.718430             -16.464617
# 101              -1.686864             -16.034858
# 102              -2.204995             -20.949982
# 103              -2.161443             -19.992328
# 104              -0.211347             -14.663908
# 105              -2.752177             -19.047412
# 106              -2.236669             -11.027879
# 107              -3.426296             -19.421970
# 108               0.336359             -12.453718
# 109               0.386846              -9.460993
# 110               0.168452             -13.890066
# 111               0.697571             -11.315742
# 112               0.469666              -9.135514
# 113               0.542810             -11.499912
# 114               0.501647              -9.590726
# 115               0.009754              -6.472165
# 116               0.482538             -12.074202
# 117               0.472506             -13.691600
# 118               0.247145              -7.529078
# 119               0.375365              -7.467665
# 120               0.104688              -6.871276
# 121               0.330476              -7.240948
# 122               0.399814             -12.076064
# 123               0.655562             -10.667507
# 124               0.510813             -11.351849
# 125              -0.719033              -5.922632
# 126               0.680382             -13.086039
# 127               0.184193              -6.307560
# 128               0.564094             -11.978800
# 129               0.211930             -13.682378
# 130               0.767881             -13.422624
# 131               0.532703             -13.987955
# 132               0.264723             -11.482539
# 133               0.546280              -9.716198
# 134               0.699696             -12.995664
# 135               0.039120              -5.892444
# 136               0.555662             -10.069093
# 137               0.614758              -7.583038
# 138               0.614695              -9.216744
# 139               0.616070              -9.056296
# 140               0.492240             -11.237229
# 141               0.543667             -10.183031
# 142               0.392674             -11.729773
# 143               0.531539             -10.428954
# 144               0.194156             -12.756866
# 145               0.515708             -10.687614
# 146              -0.098908              -4.653221
# 147               0.382411              -5.920422
# 148               0.431432             -13.416643
# 149              -0.042222             -11.366194
# 150               0.240792             -14.046136
# 151               0.731771             -14.199084
# 152               0.594361              -9.092738
# 153               0.469646             -11.294858
# 154               0.580856              -9.278852
# 155              -1.327098             -11.641580
# 156               0.508066             -10.490619
# 157              -0.386372              -7.302897
# 158               0.952377             -13.733327
# 159               0.569322              -9.130406
# 160               0.413906             -10.381644
# 161               0.780776             -14.126457
# 162               0.830522             -15.302582
# 163               0.152237             -10.505871
# 164               0.606533             -13.065937
# 165               0.444195              -9.821184
# 166               0.635537             -16.593843
# 167               0.026473              -4.524944
# 168              -0.550669             -10.195301
# 169               0.040697             -13.140577
# 170              -0.047541             -11.445075
# 171              -1.023883              -7.165526
# 172               0.038328              -4.588849
# 173              -0.247365              -3.439933
# 174              -0.755938              -3.410913
# 175              -0.764258              -6.772525
# 176               0.066319              -4.338022
# 177              -0.071531              -3.645669
# 178              -0.182481              -5.472630
# 179              -1.329622              -2.521561
# 180              -0.269921              -6.027411
# 181              -0.469710              -1.958952
# 182              -0.554120              -1.704237
# 183              -1.307346              -1.999041
# 184              -1.335378              -2.423618
# 185              -0.568113              -3.186265
# 186              -0.563012              -2.440641
# 187              -1.199835              -2.435009
# 188              -6.456618              -0.668875
# 189              -0.688482              -2.344213
# 190              -3.163118              -0.699329
# 191              -6.661044              -0.730512
# 192              -2.690408              -0.819238
# 193              -2.097458              -2.164614
# 194              -0.933122              -1.937780
# 195              -2.657100              -0.934333
# 196              -2.445893              -0.987583
# 197              -1.068652              -1.785881
# 198              -2.336468              -1.096312
# 199              -4.498208              -1.130511
# 200              -1.837766              -1.313724
# 201              -1.139449              -1.662461
# 202              -1.314643              -1.525892
# 203              -2.645790              -1.352362
# 204              -1.537488              -1.595370
# 205              -1.406263              -2.713769
# 206              -1.534982              -1.410999
# 207              -1.422619              -2.313630
# 208              -1.424236              -2.698574
# 209              -1.476448              -1.467740
# 210              -2.060347              -1.495149
# 211              -3.699113              -2.179890
# 212              -1.580032              -1.924512
# 213              -2.649440              -1.653244
# 214              -0.838980             -10.272161
# 215              -1.728466              -9.567677
# 216              -1.337921              -8.787155
# 217              -0.591914              -9.668986
# 218              -1.913013             -10.370149
# 219              -0.862777             -12.186822
# 220              -0.236290             -10.474539
# 221              -0.847821             -12.188704
# 222              -1.922691             -11.459604
# 223              -0.375752             -11.875312
# 224              -0.743696              -8.055713
# 225              -0.004932             -10.590627
# 226               0.001037             -11.303273
# 227              -1.106793              -9.040747
# 228              -1.608908              -8.065387
# 229              -1.871281             -12.156515
# 230              -0.523281             -12.181860
# 231               0.065103             -11.774923
# 232               0.135992             -10.342544
# 233              -1.732201              -9.942453
# 234               0.179978             -12.271526
# 235              -1.356012             -13.100620
# 236              -2.130993              -8.597658
# 237              -0.538303              -6.974910
# 238              -0.749705              -6.150480
# 239              -0.215878              -6.454060
# 240              -1.105365              -6.442338
# 241              -1.202126              -6.044197
# 242              -0.133994              -5.246890
# 243              -0.116751              -5.772901
# 244              -0.242836              -7.014751
# 245              -1.055582              -4.757990
# 246              -0.618909              -5.749434
# 247              -0.911247              -6.402356
# 248              -0.652196              -4.858442
# 249              -0.131722              -7.634328
# 250              -0.263377              -5.071480
# 251              -0.921153              -5.104566
# 252              -0.984758              -5.107914
# 253               0.003887              -8.656364
# 254              -0.705743              -4.164197
# 255              -0.217091              -6.229712
# 256               0.015659              -6.852371
# 257              -0.169535              -4.528701
# 258               0.102828              -7.604358
# 259              -0.262671              -7.966207
# 260               0.297488              -8.349383
# 261               0.072935              -8.867245
# 262              -0.123056              -8.687270
# 263               0.095433              -5.885973
# 264              -1.389233              -4.646718
# 265              -0.372574              -4.971157
# 266              -0.565508              -6.420073
# 267              -1.356213              -7.830843
# 268              -0.806908              -5.831787
# 269              -0.590764              -4.345115
# 270              -1.183024              -4.793310
# 271               0.519885              -9.380466
# 272              -0.973895              -7.430055
# 273               0.446859              -8.438345
# 274               0.355985              -7.763172
# 275              -0.056000              -5.881581
# 276              -0.423327              -5.084573
# 277              -0.172753              -9.026152
# 278              -0.003949              -5.799725
# 279              -0.195721              -4.017963
# 280               0.413069              -7.837491
# 281               0.192037              -5.846866
# 282               0.090014              -5.883681
# 283              -0.013908             -10.493112
# 284               0.731117              -9.223592
# 285               0.383875              -7.662759
# 286              -0.337283              -4.448878
# 287              -1.336988              -4.235491
# 288              -0.272632              -6.690968
# 289               0.612272              -8.362528
# 290               0.316769              -6.160710
# 291               0.360279              -8.314631
# 292              -0.307759              -4.473672
# 293              -0.526873             -10.188201
# 294               0.441624              -6.443523
# 295              -0.045708              -6.094458
# 296               0.498083              -6.899724
# 297               0.563879              -7.969733
# 298               0.335072              -7.345479
# 299               0.745850             -10.697541
# 300               0.369576             -10.445552
# 301              -0.289311              -5.582595
# 302               0.637681              -8.165172
# 303               0.473333              -8.541316
# 304               0.272602              -9.120597
# 305               0.380532             -11.525247
# 306               0.219980              -8.290752
# 307               0.535660             -10.209317
# 308               0.293859              -4.655637
# 309              -0.062814              -3.978519
# 310               0.680836             -12.375001
# 311               0.430940              -9.286104
# 312               0.627581              -8.190409
# 313              -0.408285              -2.893854
# 314              -0.697031              -6.180804

# %%
# ============================================================
# EXPORT CSV SIMPLE : identifiant + indice
# ============================================================

# Choisis le DataFrame à exporter
# Pour dataset4 :
df_export_source = df_d4_pred.copy()

# Si tu veux le faire pour dataset3, remplace par :
# df_export_source = df_d3_pred.copy()

# Labels présents
labels = df_export_source["final_label"].unique().tolist()

# Mapping imposé
label_to_index = {
    "normal": 0,
    "fault_1": 1
}

# Les autres labels prennent 2, 3, 4...
other_labels = sorted([label for label in labels if label not in label_to_index])

for idx, label in enumerate(other_labels, start=2):
    label_to_index[label] = idx

print("Mapping utilisé :")
print(label_to_index)

# Création du CSV final
df_export = pd.DataFrame()
df_export["identifiant"] = df_export_source[ID_COL]
df_export["indice"] = df_export_source["final_label"].map(label_to_index)

# Vérification
print(df_export.head())
print(df_export["indice"].value_counts().sort_index())

# Export CSV
df_export.to_csv("dataset4_classification_indices.csv", index=False)

print("CSV généré : dataset4_classification_indices.csv")
# Out:
# Mapping utilisé :
# {'normal': 0, 'fault_1': 1, 'd2_defect_1': 2, 'd4_new_defect_1': 3, 'd4_new_defect_2': 4, 'd4_new_defect_3': 5, 'd4_new_defect_4': 6, 'd4_new_defect_5': 7}
#   identifiant  indice
# 0   07QH7HPGI       2
# 1   07V3DLJ40       7
# 2   09XN3N7LX       6
# 3   0B9FRWJVR       0
# 4   0CDF1G71M       1
# indice
# 0    77
# 1    24
# 2    35
# 3    28
# 4    30
# 5    15
# 6    64
# 7    42
# Name: count, dtype: int64
# CSV généré : dataset4_classification_indices.csv
